# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#
# Критические ❌ комментарии
#
# + принять решение после проверки корректности заполнения пропусков синтетическими данными
# + вернуть пропуски в колонку со скоростью продаж
# + завершить фильтрацию редких значений в п. 2.4, стоит использовать больше гистограмм
# + добавить гистограмм в п.4.1
# + пересчитать скорость продаж
# + поправить фильтрацию по значениям скорости продаж — удалили более 10% данных
# + исправить выполнение п. 4.3, мы строим 8 обязательных графиков и изучаем зависимость общей стоимости от 8-ми параметров, а не от стоимости квадратного метра
# + подправить выполнение пункта 4.5 и исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие
#
# инструкцию для корректного выполнения проекта можно найти в трекере, в брифе проекта, оставляю инструкцию в простом виде

# %% [markdown]
# Инструкция по выполнению проекта
#
# Шаг 1. Откройте файл с данными и изучите общую информацию
# Путь к файлу: /datasets/real_estate_data.csv
# Скачать датасет
# Загрузите данные из файла в датафрейм.
# Изучите общую информацию о полученном датафрейме.
# Постройте общую гистограмму для всех числовых столбцов таблицы. Например, для датафрейма data это можно сделать командой data.hist(figsize=(15, 20)).
#
# Шаг 2. Предобработка данных
# Найдите и изучите пропущенные значения в столбцах:
#
# Определите, в каких столбцах есть пропуски.
# Заполните пропущенные значения там, где это возможно. Например, если продавец не указал число балконов, то, скорее всего, в его квартире их нет. Такие пропуски правильно заменить на 0. Если логичную замену предложить невозможно, то оставьте эти значения пустыми. Пропуски — тоже важный сигнал, который нужно учитывать.
# В ячейке с типом markdown укажите причины, которые могли привести к пропускам в данных.
# Рассмотрите типы данных в каждом столбце:
#
# Найдите столбцы, в которых нужно изменить тип данных.
# Преобразуйте тип данных в выбранных столбцах.
# В ячейке с типом markdown поясните, почему нужно изменить тип данных.
# Изучите уникальные значения в столбце с названиями и устраните неявные дубликаты. Например, «поселок Рябово» и «поселок городского типа Рябово», «поселок Тельмана» и «посёлок Тельмана» — это обозначения одних и тех же населённых пунктов. Вы можете заменить названия в существующем столбце или создать новый с названиями без дубликатов.
# Найдите и устраните редкие и выбивающиеся значения. Например, в столбце ceiling_height может быть указана высота потолков 25 м и 32 м. Логично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м. Попробуйте обработать аномалии в этом и других столбцах.
#
# Если природа аномалии понятна и данные действительно искажены, то восстановите корректное значение.
# В противном случае удалите редкие и выбивающиеся значения.
# В ячейке с типом markdown опишите, какие особенности в данных вы обнаружили.
#
# Шаг 3. Добавьте в таблицу новые столбцы со следующими параметрами:
# цена одного квадратного метра;
# день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# месяц публикации объявления;
# год публикации объявления;
# тип этажа квартиры (значения — «‎первый», «последний», «другой»);
# расстояние до центра города в километрах (переведите из м в км и округлите до целых значений).
#
#     Шаг 4. Проведите исследовательский анализ данных:
#     Изучите следующие параметры объектов:
#
#     общая площадь;
#     жилая площадь;
#     площадь кухни;
#     цена объекта;
#     количество комнат;
#     высота потолков;
#     этаж квартиры;
#     тип этажа квартиры («первый», «последний», «другой»);
#     общее количество этажей в доме;
#     расстояние до центра города в метрах;
#     расстояние до ближайшего аэропорта;
#     расстояние до ближайшего парка;
#     день и месяц публикации объявления.
#
#     Постройте отдельные гистограммы для каждого из этих параметров. Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.
#
#     Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней было размещено каждое объявление.
#
#     Постройте гистограмму.
#     Посчитайте среднее и медиану.
#     В ячейке типа markdown опишите, сколько времени обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?
#
#     Какие факторы больше всего влияют на общую (полную) стоимость объекта?
#      Изучите, зависит ли цена от:
#     общей площади;
#     жилой площади;
#     площади кухни;
#     количества комнат;
#     этажа, на котором расположена квартира (первый, последний, другой);
#     даты размещения (день недели, месяц, год).
#     Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
#
#     Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце locality_name.
#     Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.
#
#     Шаг 5. Напишите общий вывод
#     Опишите полученные результаты и зафиксируйте основной вывод проведённого исследования.
#
# Оформление
# Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.
#
#     Описание данных
#     airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
#     balcony — число балконов
#     ceiling_height — высота потолков (м)
#     cityCenters_nearest — расстояние до центра города (м)
#     days_exposition — сколько дней было размещено объявление (от публикации до снятия)
#     first_day_exposition — дата публикации
#     floor — этаж
#     floors_total — всего этажей в доме
#     is_apartment — апартаменты (булев тип)
#     kitchen_area — площадь кухни в квадратных метрах (м²)
#     last_price — цена на момент снятия с публикации
#     living_area — жилая площадь в квадратных метрах (м²)
#     locality_name — название населённого пункта
#     open_plan — свободная планировка (булев тип)
#     parks_around3000 — число парков в радиусе 3 км
#     parks_nearest — расстояние до ближайшего парка (м)
#     ponds_around3000 — число водоёмов в радиусе 3 км
#     ponds_nearest — расстояние до ближайшего водоёма (м)
#     rooms — число комнат
#     studio — квартира-студия (булев тип)
#     total_area — общая площадь квартиры в квадратных метрах (м²)
#     total_images — число фотографий квартиры в объявлении

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Павел :)  Если не ошибаюсь это уже третья полностью обновленная версия проекта ..., даже если происходит глобальный сбой ... можно попросить копию проекта у ревьюера ...

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Не стоит тратить время и ресурсы на заполнение пропусков в колонках
#
#         'living_area',  'kitchen_area'
#
# мы пока не проходили оптимального способа для заполнения пропусков ...
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Павел :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Проект: Исследовательский анализ данных

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-info">
#
# **Крик студента**
#     Платформа/тренажер/аналог Colab - глючит по-страшному, возможно глючит не просто платформа, а именно у мен из-за перегруза... У меня постоянно все скачет и удаляется. Загружаю исходник с локального сервера.
# </div>
# </div>

# %% [markdown]
# **Описание проекта**
#
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений за несколько лет о продаже квартир в Санкт-Петербурге и соседних населённых пунктах.
# Ваша задача — выполнить предобработку данных и изучить их, чтобы найти интересные особенности и зависимости, которые существуют на рынке недвижимости.
# О каждой квартире в базе содержится два типа данных: добавленные пользователем и картографические. Например, к первому типу относятся площадь квартиры, её этаж и количество балконов, ко второму — расстояния до центра города, аэропорта и ближайшего парка.

# %% [markdown]
# ## Откройте файл с данными и изучите общую информацию

# %% [markdown]
# Подключение необходимых библиотек.

# %%
import pandas as pd
import copy
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
#flats_sales_data = pd.read_csv('D:\PyProject\Yandex Practicum\Исследовательский анализ данных/real_estate_data.csv', sep="\t")
flats_sales_data = pd.read_csv('real_estate_data.csv', sep="\t")
print(flats_sales_data.info())
flats_sales_data.head()
old_len_flats_sales_data = flats_sales_data.shape[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Отобразим уникальные значения по каждому столбцу.

# %%
for column in flats_sales_data.columns:
    print(column)
    print(flats_sales_data[column].unique())
    print()
# Out:
# total_images
# [20  7 10  0  2  6  5 18  9  1 16 11  8 12 13  3 15 17 14 19 32  4 35 39
#  23 21 27 30 24 25 28 31 22 29 26 50 42 37]
#
# last_price
# [13000000.  3350000.  5196000. ...  6151120. 21400000. 11475000.]
#
# total_area
# [108.    40.4   56.   ...  66.86 133.81  76.75]
#
# first_day_exposition
# ['2019-03-07T00:00:00' '2018-12-04T00:00:00' '2015-08-20T00:00:00' ...
#  '2014-12-29T00:00:00' '2016-09-12T00:00:00' '2015-07-19T00:00:00']
#
# rooms
# [ 3  1  2  4  5  6  0  7 11  8 14 10 15  9 19 16 12]
#
# ceiling_height
# [  2.7     nan   3.03   2.5    2.67   2.56   3.05   2.75   2.6    2.9
#    2.8    2.55   3.     2.65   3.2    2.61   3.25   3.45   2.77   2.85
#    2.64   2.57   4.15   3.5    3.3    2.71   4.     2.47   2.73   2.84
#    3.1    2.34   3.4    3.06   2.72   2.54   2.51   2.78   2.76  25.
#    2.58   3.7    2.52   5.2    2.87   2.66   2.59   2.     2.45   3.6
#    2.92   3.11   3.13   3.8    3.15   3.55   3.16   3.62   3.12   2.53
# ...

# %% [markdown]
# Нижеприведенная Таблица dupl1 добавлена уже после предобработки, чтобы в самом конце более точно идентифицировать дубликаты (в конце предобработки сравним её с таблицей dupl2)
#
# Для идентификации дубликатов возьмем совпадения по нескольким столбцам - по тем в которых были все значения изначально и особенно в которых маловероятны совпадения: 1) first_day_exposition (++ его почти не меняли и много разных дат), 2) last_price(++здесь должно быть мало повторении), 3) total_area 4) total_images (вообще не меняли) - этого ВПОЛНЕ достаточно

# %%
dupl1 = flats_sales_data[flats_sales_data[['total_images', 'last_price','first_day_exposition','total_area']].duplicated(keep=False)]
dupl1.sort_values(by='total_images')
print('ТАБЛИЦА dupl1 :')
display(dupl1.sort_values(by='first_day_exposition'))
# Out:
# ТАБЛИЦА dupl1 :
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 19052             3   4370000.0       38.00  2016-06-23T00:00:00      1
# 19325             3   4370000.0       38.00  2016-06-23T00:00:00      1
# 9661              1   2533531.0       42.50  2016-09-08T00:00:00      1
# 18425             1   2533531.0       42.50  2016-09-08T00:00:00      1
# 10099            10   4400000.0       44.00  2017-11-22T00:00:00      1
# 21142            10   4400000.0       44.00  2017-11-22T00:00:00      2
# 14739            10   5142565.0       54.65  2018-10-01T00:00:00      2
# 18624            10   5142565.0       54.65  2018-10-01T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 19052             NaN           9.0         19.5      1          NaN  ...
# 19325             NaN           9.0          NaN      2          NaN  ...
# 9661             2.56          18.0         19.8      7        False  ...
# ...

# %% [markdown]
# Построим общую гистограмму

# %%
flats_sales_data.hist(figsize=(15, 20))
# Out:
# array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
# ...

# %%
flats_sales_data['first_day_exposition'].value_counts()
# Out:
# 2018-02-01T00:00:00    368
# 2017-11-10T00:00:00    240
# 2017-10-13T00:00:00    124
# 2017-09-27T00:00:00    111
# 2018-03-26T00:00:00     97
#                       ...
# 2018-05-20T00:00:00      1
# 2015-05-15T00:00:00      1
# 2015-01-12T00:00:00      1
# 2015-12-19T00:00:00      1
# 2015-07-19T00:00:00      1
# Name: first_day_exposition, Length: 1491, dtype: int64

# %%
flats_sales_data['studio'].value_counts()
# Out:
# False    23550
# True       149
# Name: studio, dtype: int64

# %%
flats_sales_data[flats_sales_data['rooms']==0]['studio'].value_counts()
# Out:
# True     138
# False     59
# Name: studio, dtype: int64

# %%
flats_sales_data[flats_sales_data['rooms']==1]['studio'].value_counts()
# Out:
# False    8036
# True       11
# Name: studio, dtype: int64

# %%
flats_sales_data[flats_sales_data['studio']]['rooms'].value_counts()
# Out:
# 0    138
# 1     11
# Name: rooms, dtype: int64

# %%
flats_sales_data['living_area'].value_counts()
# Out:
# 18.00     882
# 17.00     675
# 30.00     598
# 16.00     486
# 20.00     481
#          ...
# 76.70       1
# 39.41       1
# 124.90      1
# 36.07       1
# 42.55       1
# Name: living_area, Length: 1782, dtype: int64

# %%
flats_sales_data['is_apartment'].isna().value_counts()
# Out:
# True     20924
# False     2775
# Name: is_apartment, dtype: int64

# %%
flats_sales_data['kitchen_area'].isna().value_counts()
# Out:
# False    21421
# True      2278
# Name: kitchen_area, dtype: int64

# %%
flats_sales_data['parks_around3000'].isna().value_counts()
# Out:
# False    18181
# True      5518
# Name: parks_around3000, dtype: int64

# %%
flats_sales_data['parks_around3000'].value_counts()
# Out:
# 0.0    10106
# 1.0     5681
# 2.0     1747
# 3.0      647
# Name: parks_around3000, dtype: int64

# %%
flats_sales_data['parks_nearest'].isna().value_counts()
# Out:
# True     15620
# False     8079
# Name: parks_nearest, dtype: int64

# %%
flats_sales_data['ponds_around3000'].isna().value_counts()
# Out:
# False    18181
# True      5518
# Name: ponds_around3000, dtype: int64

# %%
flats_sales_data['ponds_around3000'].value_counts()
# Out:
# 0.0    9071
# 1.0    5717
# 2.0    1892
# 3.0    1501
# Name: ponds_around3000, dtype: int64

# %%
flats_sales_data['ponds_nearest'].isna().value_counts()
# Out:
# True     14589
# False     9110
# Name: ponds_nearest, dtype: int64

# %%
flats_sales_data['days_exposition'].isna().value_counts()
# Out:
# False    20518
# True      3181
# Name: days_exposition, dtype: int64

# %%
flats_sales_data['days_exposition'].value_counts()
# Out:
# 45.0      880
# 60.0      538
# 7.0       234
# 30.0      208
# 90.0      204
#          ...
# 1021.0      1
# 1362.0      1
# 1105.0      1
# 795.0       1
# 971.0       1
# Name: days_exposition, Length: 1141, dtype: int64

# %%
flats_sales_data['days_exposition'][flats_sales_data['days_exposition'] == 0]
# Out:
# Series([], Name: days_exposition, dtype: float64)

# %%
flats_sales_data[flats_sales_data['locality_name'].isna()].head()
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 1097             3   8600000.0        81.7  2016-04-15T00:00:00      3
# 2033             6   5398000.0        80.0  2017-05-30T00:00:00      3
# 2603            20   3351765.0        42.7  2015-09-20T00:00:00      1
# 2632             2   5130593.0        62.4  2015-10-11T00:00:00      2
# 3574            10   4200000.0        46.5  2016-05-28T00:00:00      2
#
#       ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 1097            3.55           5.0         50.8      2          NaN  ...
# 2033             NaN           4.0         42.6      2          NaN  ...
# 2603             NaN          24.0         15.6      3          NaN  ...
# 2632             NaN          24.0         33.1     21          NaN  ...
# 3574             NaN           5.0         30.8      5          NaN  ...
#
#       kitchen_area  balcony  locality_name  airports_nearest  \
# ...

# %% [markdown]
# **Вывод**
# Выделение типов переменных в flats_sales_data:
#
# * *Категориальные*: locality_name.
# * *Количественные*: total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, kitchen_area, balcony, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_nearest, ponds_around3000, days_exposition.
# * *Логические*: is_apartment, studio, open_plan.
#
# Выявлены следующие аномалии:
#
# *Случайного типа:*
# * Значения rooms 1 или 0 при указании квартиры как студии. Здесь можно ошибиться не зная четких правил по определению количество комнат в студии. Или продавец не указал количество комнат, т.к. определен тип квартиры студия.
# * Значения False в studio при количестве комнат = 0. Относится к пропуску значения комнат, никак не связанных со студией. Продавец не указал количество комнат.
# * Значения NaN в столбце kitchen_area. Возможная потеря данных. Легко восстановить имея данные об общей площади.
# * Значения NaN в столце balcony. Возможная потеря данных или неуказание количество балконов в виду их отсутсвия.
# * Значения NaN в столце parks_around3000 и ponds_around3000. Возможная потеря данных или неуказание количество парков или прудов в виду их отсутсвия.
# * Значения NaN в locality_name, cityCenters_nearest. days_exposition, ceiling_height, floors_total. Возможные потери данных.
#
# *Неслучайного типа:*
# * Значение 0 в total_images. Возможно кто-то специально не хочет показывать квартиру ввиду ее отсутсвия или желания показать квартиру только при встрече.
# * Значение времени 00:00:00 в first_day_exposition. Точное время отправки на сайт продажи не требуется, нужен только день.
# * Значения NaN в is_apartment. Около 21000 квартир не имеют статуса в этой категории. Возможно продавцы не указали, жилая квартира для постоянного проживания или апартаменты для временного в виду своего незнания.
# * Значения NaN в столце parks_nearest и ponds_nearest. Здесь можно было ориентироваться на количество пустых и 0 значений в столбце parks_around3000 и ponds_around3000 соответсвенно. Вывод сделан на примерной сумме пустых значений и 0.
# * Совпадение по количеству пропусков в parks_around3000 и ponds_around3000. Значит продавцы не указали эти факторы как значимые в своей публикации.
#
# Числовые аномалии и несоотвествие значений реальности обработаем в шаге "Предобработка данных".

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Проведем сводный анализ пропусков по каждому столцу и выявим столбцы:
# - Где нужно избавиться от пропуков.
# - Невлияющие на гипотезы.
# - Невозможно восстановить.

# %%
count_of_index = flats_sales_data.shape[0]
print('Всего значений в данных:', count_of_index)
for column in flats_sales_data.columns:
    isna_count = flats_sales_data[column].isna().value_counts()
    print('Количество пропусков в', column, ': ', count_of_index - isna_count[0])
# Out:
# Всего значений в данных: 23699
# Количество пропусков в total_images :  0
# Количество пропусков в last_price :  0
# Количество пропусков в total_area :  0
# Количество пропусков в first_day_exposition :  0
# Количество пропусков в rooms :  0
# Количество пропусков в ceiling_height :  9195
# Количество пропусков в floors_total :  86
# Количество пропусков в living_area :  1903
# Количество пропусков в floor :  0
# Количество пропусков в is_apartment :  20924
# Количество пропусков в studio :  0
# Количество пропусков в open_plan :  0
# Количество пропусков в kitchen_area :  2278
# Количество пропусков в balcony :  11519
# Количество пропусков в locality_name :  49
# Количество пропусков в airports_nearest :  5542
# Количество пропусков в cityCenters_nearest :  5519
# Количество пропусков в parks_around3000 :  5518
# Количество пропусков в parks_nearest :  15620
# Количество пропусков в ponds_around3000 :  5518
# Количество пропусков в ponds_nearest :  14589
# ...

# %% [markdown]
# *Столбцы с восстановлением пропуков*
# - floors_total. Необходим для категоризации данных по расположению этажа в жилом доме.
# - living_area. Ключевой фактор для создания соотношения к общей площади.
# - kitchen_area. Ключевой фактор для создания соотношения к общей площади.
# - cityCenters_nearest. Ключевой фактор для определения удаленности от центра Санкт-Петербурга.
# - locality_name. Этот столбец имеет значения для гипотез. Но его можно восстановить, зная местоположение от центра.
#
# *Столцбы, неимеющие значения для гипотез*
# - is_apartment. Определение типа жилого помещения на постоянной основе с регистрацией, т.е. квартиры, и апартамента не имеет никакого значения для гипотез.
# - balcony. Этот столбец не имеет значения для гипотез. Но его легко восстановить.
# - parks_nearest и ponds_nearest. Эти столбцы не имеею значения для гипотез. Теоретически их можно восстановить из столбцов parks_around3000 и ponds_around3000.
# - airports_nearest, parks_around3000 и ponds_around3000. Количество в около 5500 значений говорит или о системной ошибке, или создании такого количество предложений с пропусками в этих значениях. Можно ориентироваться в пропусках на местоположение в locality_name.
#
# *Стобцы, воостановления значений которых невозможно*
# - ceiling_height. Пропущенных значений слишком много для достоверного восстановления картины.
# - locality_name и cityCenters_nearest, значения которых NaN. Эти предложения не подходят для некоторых гипотез. Соотвественно их можно удалить
# - days_exposition. Важный для нас столбец для определения успешности продаж, проставляет значение только по снятию продаж

# %% [markdown]
# ### Проверка на нереальные значения
#
# Проверим нереальные значения по столбцам...

# %% [markdown]
# #### Столбец "total_images"

# %%
display(flats_sales_data['total_images'].value_counts())
flats_sales_data['total_images'].hist(bins=50, range=(1,51))
# Out:
# 10    1798
# 9     1725
# 20    1694
# 8     1585
# 7     1521
# 6     1482
# 11    1362
# 5     1301
# 12    1225
# 0     1059
# 13    1015
# 4      986
# 14     986
# 15     948
# 1      872
# 3      769
# 16     761
# 17     650
# 18     642
# 2      640
# 19     603
# 23      16
# 21      12
# 24       8
# 22       8
# 26       5
# 32       4
# 28       4
# 50       3
# 29       3
# 27       2
# 30       2
# 35       2
# 31       2
# 42       1
# 25       1
# 39       1
# 37       1
# Name: total_images, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# **Вывод: Всё корректно. На этом закончим. Столбец оставим.**

# %% [markdown]
# #### Столбец "last_price"**

# %% [markdown]
# Поменяем сразу тип на int

# %%
flats_sales_data['last_price'] = flats_sales_data['last_price'].astype(int)

# %%
##################################################################################
#------- НАПИШЕМ ФУНКЦИЮ ДЛЯ ОПИСАНИЯ ЧИСЛОВЫХ СТОЛБЦОВ ( Данные + Графика )------ 
def descr_numeric(target_column):  # аргумент функции название столбца
    print(flats_sales_data[target_column].head(7), flats_sales_data[target_column].describe())
    flats_sales_data.boxplot(column=target_column, figsize=(3,7)); 
    plt.show()
    flats_sales_data[target_column].hist(figsize=(16,3), bins=100);
#---------------------------------------------------------------------------------
##################################################################################

descr_numeric('last_price')
# Out:
# 0    13000000
# 1     3350000
# 2     5196000
# 3    64900000
# 4    10000000
# 5     2890000
# 6     3700000
# Name: last_price, dtype: int32 count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Тип поменяли. Есть как сильно больщие (763млн) так очень маленькие значения (12190р). Рассмотрим всё на графиках.

# %%
basket = 100
flats_sales_data.hist('last_price', bins=basket, figsize=(14,3), range=(0, 600001));
flats_sales_data.hist('last_price', bins=basket, figsize=(14,3), range=(600000, 60000001));
flats_sales_data.hist('last_price', bins=basket, figsize=(14,3), range=(60000000, 800000000));

# %% [markdown]
# Есть "Выбросы". Избавимся от них, чтобы данные были более равномерные (хотя можно и оставить их совсем мало, влияние будет незначительным). Оставим все что >400тыс.руб и <100млн.р., остальное удалим

# %%
display(flats_sales_data.head())
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0  2019-03-07T00:00:00      3
# 1             7     3350000        40.4  2018-12-04T00:00:00      1
# 2            10     5196000        56.0  2015-08-20T00:00:00      2
# 3             0    64900000       159.0  2015-07-24T00:00:00      3
# 4             2    10000000       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
flats_sales_data = flats_sales_data.loc[(flats_sales_data['last_price']>400000) & (flats_sales_data['last_price']<100000000)]
#flats_sales_data = flats_sales_data.query('400000 < last_price < 100000000')
flats_sales_data.reset_index(inplace=True, drop=True)
print(flats_sales_data.index)
print(flats_sales_data['last_price'].describe())
# Out:
# RangeIndex(start=0, stop=23661, step=1)
# count    2.366100e+04
# mean     6.251771e+06
# std      6.424397e+06
# min      4.300000e+05
# 25%      3.400000e+06
# 50%      4.635000e+06
# 75%      6.750000e+06
# max      9.900000e+07
# Name: last_price, dtype: float64

# %%
display(flats_sales_data.query('400000 > last_price and last_price < 100000000'))
display(flats_sales_data.tail())
print(flats_sales_data.index)
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23656             9     9700000      133.81  2017-03-21T00:00:00      3
# 23657            14     3100000       59.00  2018-01-15T00:00:00      3
# 23658            18     2500000       56.70  2018-02-11T00:00:00      2
# 23659            13    11475000       76.75  2017-03-28T00:00:00      2
# 23660             4     1350000       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23656             3.7           5.0         73.3      3          NaN  ...
# ...

# %% [markdown]
# #### Столбец "total_area"

# %%
descr_numeric('total_area')
# Out:
# 0    108.0
# 1     40.4
# 2     56.0
# 3    159.0
# 4    100.0
# 5     30.4
# 6     37.3
# Name: total_area, dtype: float64 count    23661.000000
# mean        59.925974
# std         33.470704
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.600000
# max        590.000000
# Name: total_area, dtype: float64

# %%
flats_sales_data.hist('total_area', bins=basket, figsize=(14,3), range=(0, 600));

# %% [markdown]
# Посмотрим как распределено все что выше 200кв.м

# %%
flats_sales_data.hist('total_area', bins=basket, figsize=(14,3), range=(200, 600));

# %% [markdown]
# **ВЫВОД:**
# Разброс довольно равномерный ( Мин - Макс небольше 50 раз). Оставим всё как есть. Корректный столбец

# %% [markdown]
# #### Столбец "first_day_exposition "

# %%
print(flats_sales_data['first_day_exposition'].head(5))
print(flats_sales_data['first_day_exposition'].describe())
# Out:
# 0    2019-03-07T00:00:00
# 1    2018-12-04T00:00:00
# 2    2015-08-20T00:00:00
# 3    2015-07-24T00:00:00
# 4    2018-06-19T00:00:00
# Name: first_day_exposition, dtype: object
# count                   23661
# unique                   1490
# top       2018-02-01T00:00:00
# freq                      368
# Name: first_day_exposition, dtype: object

# %%
flats_sales_data['first_day_exposition'] = pd.to_datetime(flats_sales_data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
print(flats_sales_data['first_day_exposition'].head(5))
print(flats_sales_data['first_day_exposition'].describe())
# Out:
# 0   2019-03-07
# 1   2018-12-04
# 2   2015-08-20
# 3   2015-07-24
# 4   2018-06-19
# Name: first_day_exposition, dtype: datetime64[ns]
# count                   23661
# unique                   1490
# top       2018-02-01 00:00:00
# freq                      368
# first     2014-11-27 00:00:00
# last      2019-05-03 00:00:00
# Name: first_day_exposition, dtype: object

# %% [markdown]
# **ВЫВОД:** Столбец с датой исправили. Все в порядке.

# %% [markdown]
# #### Столбец "rooms"

# %%
descr_numeric('rooms')
print(flats_sales_data['rooms'].value_counts())
# Out:
# 0    3
# 1    1
# 2    2
# 3    3
# 4    2
# 5    1
# 6    1
# Name: rooms, dtype: int64 count    23661.000000
# mean         2.065720
# std          1.069614
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64
# 1     8047
# 2     7938
# 3     5810
# 4     1171
# 5      316
# 0      197
# 6      100
# 7       54
# 8       10
# 9        8
# 10       3
# 11       2
# 14       2
# 15       1
# 19       1
# 16       1
# Name: rooms, dtype: int64

# %% [markdown]
# Есть значения 0 комнат (такого не бывает). Посмотрим значения площадей квартир в этих строках

# %%
print(flats_sales_data.query('rooms == 0')['total_area'].describe())
# Out:
# count    197.000000
# mean      29.279746
# std       25.855264
# min       15.500000
# 25%       24.050000
# 50%       26.050000
# 75%       28.400000
# max      371.000000
# Name: total_area, dtype: float64

# %% [markdown]
# ВСЕГО 197 ЗНАЧЕНИЙ с 0.
# Видно что бодьшинство значений 'total_area' меньше 30кв.м - это 1 комнатные. Рассмотрим поподробнее большие значения.

# %%
print(flats_sales_data.query('rooms==0 and total_area>28.4')['total_area'].sort_values())
# Out:
# 21265     28.50
# 2983      28.90
# 12973     29.00
# 19846     29.00
# 18521     29.00
# 15688     29.00
# 3426      29.00
# 23554     29.00
# 1171      29.00
# 2049      29.00
# 10400     29.10
# 7245      29.20
# 4962      29.30
# 1595      30.00
# 22829     30.00
# 7275      30.00
# 22017     30.10
# 5947      30.30
# 19705     30.50
# 13849     31.00
# 15732     31.00
# 3138      31.00
# 18000     31.00
# 6794      31.00
# 17926     31.00
# 1523      31.00
# 17778     31.10
# 1172      32.00
# 6209      32.00
# 15690     32.03
# 15680     32.20
# 6997      32.30
# 12213     32.40
# 18104     32.50
# 16495     32.80
# 21594     34.00
# 508       34.40
# 4674      35.00
# 838       35.00
# 9036      38.30
# 16106     42.10
# 7226      42.63
# 15296     43.30
# 9992      44.20
# 13594     58.40
# 21193     71.00
# 3449      73.60
# 20051     98.40
# 19363    371.00
# Name: total_area, dtype: float64

# %% [markdown]
# Рассчитаем и посмотрим средние значение площади для 1,2,3,4 комнатных квартир

# %%
for n in range(1,5):
    print(f'{n} комнатная квартира:',flats_sales_data.query('rooms == @n')['total_area'].describe())
    print()
# Out:
# 1 комнатная квартира: count    8047.000000
# mean       37.644669
# std         9.338358
# min        12.000000
# 25%        32.500000
# 50%        36.560000
# 75%        41.000000
# max       494.100000
# Name: total_area, dtype: float64
#
# 2 комнатная квартира: count    7938.000000
# mean       55.831810
# std        13.101427
# min        20.000000
# 25%        46.000000
# 50%        53.000000
# 75%        62.000000
# max       196.000000
# Name: total_area, dtype: float64
#
# 3 комнатная квартира: count    5810.000000
# mean       77.685761
# std        23.049603
# min        40.100000
# 25%        62.000000
# 50%        72.900000
# 75%        87.000000
# max       363.100000
# Name: total_area, dtype: float64
#
# 4 комнатная квартира: count    1171.000000
# mean      106.417848
# std        41.682949
# min        42.000000
# 25%        77.650000
# 50%        98.900000
# 75%       125.000000
# max       470.300000
# Name: total_area, dtype: float64

# %% [markdown]
# * Все что ниже 40 кв.м - сделаем 1 комнатными
# * от 40 до 60 кв.м - сделаем 2 комнатной
# * от 60 до 80 кв.м сделаем 3 комнатными
# * от 80 кв.м сделаем 4 комнатной

# %%
zero_room_index_list = flats_sales_data[flats_sales_data['rooms']==0].index # сохраним список индексов строк где 0 комнат (для проверки)

# %%
flats_sales_data.loc[(flats_sales_data['rooms']==0) & (flats_sales_data['total_area']<40), 'rooms'] = 1
flats_sales_data.loc[(flats_sales_data['rooms']==0) & (flats_sales_data['total_area']>40) & (flats_sales_data['total_area']<60), 'rooms'] = 2
flats_sales_data.loc[(flats_sales_data['rooms']==0) & (flats_sales_data['total_area']>60) & (flats_sales_data['total_area']<80), 'rooms'] = 3
flats_sales_data.loc[(flats_sales_data['rooms']==0) & (flats_sales_data['total_area']>80) & (flats_sales_data['total_area']<130), 'rooms'] = 4

# %%
print('Проверим какие значения по тем индексам где были 0:')
print(flats_sales_data.loc[zero_room_index_list,'rooms'].value_counts())
# Out:
# Проверим какие значения по тем индексам где были 0:
# 1    188
# 2      5
# 3      2
# 0      1
# 4      1
# Name: rooms, dtype: int64

# %% [markdown]
# проверим весь data

# %%
display(flats_sales_data.tail())
print(flats_sales_data.info())
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23656             9     9700000      133.81           2017-03-21      3
# 23657            14     3100000       59.00           2018-01-15      3
# 23658            18     2500000       56.70           2018-02-11      2
# 23659            13    11475000       76.75           2017-03-28      2
# 23660             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23656             3.7           5.0         73.3      3          NaN  ...
# 23657             NaN           5.0         38.0      4          NaN  ...
# 23658             NaN           3.0         29.7      1          NaN  ...
# 23659             3.0          17.0          NaN     12          NaN  ...
# 23660             2.5           5.0         12.3      1          NaN  ...
#
#        kitchen_area  balcony        locality_name  airports_nearest  \
# ...

# %% [markdown]
# #### Столбец "ceiling_height"

# %% [markdown]
# Нормальной высотой потолков считается дапазон 240-320см(в некоторых случаях делают натяжные потолки, гипсокартон, подвесные = это может съедать около 10см , поэтому 230см вполне тоже норма). Бывают не редко и потолки под 400см. Проанализируем всё подробно

# %%
descr_numeric('ceiling_height')
# Out:
# 0    2.70
# 1     NaN
# 2     NaN
# 3     NaN
# 4    3.03
# 5     NaN
# 6     NaN
# Name: ceiling_height, dtype: float64 count    14478.000000
# mean         2.769863
# std          1.261192
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
flats_sales_data['ceiling_height'].value_counts()
# Out:
# 2.50    3515
# 2.60    1646
# 2.70    1574
# 3.00    1110
# 2.80     992
#         ...
# 2.34       1
# 4.65       1
# 5.30       1
# 2.20       1
# 3.59       1
# Name: ceiling_height, Length: 180, dtype: int64

# %%
flats_sales_data['ceiling_height'].hist(figsize=(12,3), bins=60, range=(2.3, 4.5));
plt.show()
flats_sales_data['ceiling_height'].hist(figsize=(12,3), bins=60, range=(0,2.3));
plt.show()
flats_sales_data['ceiling_height'].hist(figsize=(12,3), bins=60, range=(4.5,40));

# %%
display(flats_sales_data.query('ceiling_height > 19 and ceiling_height < 35'))
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 355              17     3600000        55.2           2018-07-12      2
# 3139             14     2900000        75.0           2018-11-12      3
# 4634              0     4300000        45.0           2018-02-01      2
# 4867              7     3000000        25.0           2017-09-27      1
# 5066              0     3850000        30.5           2018-10-03      1
# 5236              0     2500000        54.0           2017-10-13      2
# 5659              4     4400000        50.0           2017-08-08      2
# 5797             17     8150000        80.0           2019-01-09      2
# 6235              6     3300000        44.4           2019-03-25      2
# 9363              5     3950000        42.0           2017-03-26      3
# 10757             8     3800000        58.0           2017-10-13      2
# 11269             0     1950000        37.0           2019-03-20      1
# ...

# %% [markdown]
# Судя данным из таблици (по цене, площади) это обычные квартиры с высотой от 2 до 4 метров. А двухзначные значения получились из-за того, что была пропущена запятая. Поэтому разделим эти значения на 10.

# %%
index_list = flats_sales_data.query('ceiling_height > 19 and ceiling_height < 35').index # Список индексов для проверки
flats_sales_data.loc[index_list, 'ceiling_height'] = flats_sales_data.loc[index_list, 'ceiling_height'] / 10

# %%
print(flats_sales_data.loc[index_list]['ceiling_height'])
print(flats_sales_data['ceiling_height'].tail(10))
# Out:
# 355      2.50
# 3139     3.20
# 4634     2.50
# 4867     2.70
# 5066     2.40
# 5236     2.70
# 5659     2.60
# 5797     2.70
# 6235     2.50
# 9363     2.50
# 10757    2.70
# 11269    2.50
# 14361    2.50
# 17469    2.00
# 17830    2.70
# 18517    2.50
# 20445    2.70
# 20474    2.26
# 21343    2.75
# 21790    2.70
# 22299    3.20
# 22900    2.70
# Name: ceiling_height, dtype: float64
# 23651    2.86
# 23652     NaN
# 23653    2.75
# 23654     NaN
# 23655    2.60
# 23656    3.70
# 23657     NaN
# 23658     NaN
# 23659    3.00
# 23660    2.50
# Name: ceiling_height, dtype: float64

# %% [markdown]
# **Удалим строки где некорректные значения (их мало):**
#
# * выше 35 (там только 100 -нереально, 10 тоже не реально )
# * ниже 1,9 ( это подвалы, наверно )
# * от 7 до 19 (7-9 слишком выбивается из диапазона(уто уже 3-х уровневые квартиры:)) ), 10-19 - запятую не поставили (подвальный вариант))

# %%
# print(data.query('ceiling_height>35 or ceiling_height<1.9 or 7<ceiling_height<19')['ceiling_height'])
index_list = flats_sales_data.query('ceiling_height>35 or ceiling_height<1.9 or 7<ceiling_height<19').index
print(flats_sales_data.loc[index_list, 'ceiling_height'])
# Out:
# 3465       8.00
# 5702       1.20
# 5853       8.30
# 15038     14.00
# 15719      8.00
# 16907      1.75
# 17415      8.00
# 22272     10.30
# 22553      1.00
# 22831    100.00
# Name: ceiling_height, dtype: float64

# %%
print("Кол-во строк перед удалением", len(flats_sales_data))
flats_sales_data.drop(index_list, inplace=True, axis=0)
print("Кол-во строк после удаления", len(flats_sales_data))

flats_sales_data.reset_index(inplace=True, drop=True)
display(flats_sales_data.tail())
# Out:
# Кол-во строк перед удалением 23661
# Кол-во строк после удаления 23651
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23646             9     9700000      133.81           2017-03-21      3
# 23647            14     3100000       59.00           2018-01-15      3
# 23648            18     2500000       56.70           2018-02-11      2
# 23649            13    11475000       76.75           2017-03-28      2
# 23650             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23646             3.7           5.0         73.3      3          NaN  ...
# 23647             NaN           5.0         38.0      4          NaN  ...
# 23648             NaN           3.0         29.7      1          NaN  ...
# 23649             3.0          17.0          NaN     12          NaN  ...
# 23650             2.5           5.0         12.3      1          NaN  ...
#
# ...

# %%
print(flats_sales_data['ceiling_height'].describe())
print(flats_sales_data['ceiling_height'].value_counts().head(15))
# Out:
# count    14468.000000
# mean         2.724905
# std          0.274132
# min          2.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max          5.800000
# Name: ceiling_height, dtype: float64
# 2.50    3522
# 2.60    1647
# 2.70    1582
# 3.00    1110
# 2.80     992
# 2.55     980
# 2.75     910
# 2.65     676
# 3.20     278
# 3.10     203
# 2.90     164
# 2.56     139
# 3.30     138
# 3.50     129
# 2.57     103
# Name: ceiling_height, dtype: int64

# %% [markdown]
# **Теперь, для наглядности, переведем высоту в сантиметры**

# %%
flats_sales_data['ceiling_height'] = flats_sales_data['ceiling_height'] * 100
print(flats_sales_data['ceiling_height'].describe())
# Out:
# count    14468.000000
# mean       272.490531
# std         27.413227
# min        200.000000
# 25%        251.000000
# 50%        265.000000
# 75%        280.000000
# max        580.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Теперь решим проблему с пропусками

# %%
print("Кол-во пропусков =", flats_sales_data['ceiling_height'].isna().sum())
print(flats_sales_data['ceiling_height'].describe())
print(flats_sales_data['ceiling_height'].value_counts())
# Out:
# Кол-во пропусков = 9183
# count    14468.000000
# mean       272.490531
# std         27.413227
# min        200.000000
# 25%        251.000000
# 50%        265.000000
# 75%        280.000000
# max        580.000000
# Name: ceiling_height, dtype: float64
# 250.0    3522
# 260.0    1647
# 270.0    1582
# 300.0    1110
# 280.0     992
#          ...
# 343.0       1
# 430.0       1
# 339.0       1
# 465.0       1
# 359.0       1
# Name: ceiling_height, Length: 165, dtype: int64

# %% [markdown]
# Для замены лучше всего подойдет медианное значение столбца 265см (оно не подверженно влиянию тех значений которые расположены по концам столбца, где могут быть сильные отклонения, влияющие на среднюю величину)

# %%
flats_sales_data['ceiling_height'] = flats_sales_data['ceiling_height'].fillna(265)

# %%
print("Кол-во пропусков =", flats_sales_data['ceiling_height'].isna().sum())
print()
print(flats_sales_data['ceiling_height'].describe())
# Out:
# Кол-во пропусков = 0
#
# count    23651.000000
# mean       269.582174
# std         21.749021
# min        200.000000
# 25%        260.000000
# 50%        265.000000
# 75%        270.000000
# max        580.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# И наконец поменяем тип на int

# %%
print('Длина всего data =',len(flats_sales_data))
print()
flats_sales_data['ceiling_height'] = flats_sales_data['ceiling_height'].astype('int')
print(flats_sales_data['ceiling_height'].describe())
print()
print("Тип столбца -",flats_sales_data['ceiling_height'].dtype)
# Out:
# Длина всего data = 23651
#
# count    23651.000000
# mean       269.536087
# std         21.780124
# min        200.000000
# 25%        260.000000
# 50%        265.000000
# 75%        270.000000
# max        580.000000
# Name: ceiling_height, dtype: float64
#
# Тип столбца - int32

# %% [markdown]
# #### Столбец "floors_total"

# %%
descr_numeric('floors_total')
# Out:
# 0    16.0
# 1    11.0
# 2     5.0
# 3    14.0
# 4    14.0
# 5    12.0
# 6    26.0
# Name: floors_total, dtype: float64 count    23565.000000
# mean        10.678294
# std          6.596978
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %%
print(flats_sales_data['floors_total'].value_counts())
display(flats_sales_data.query('floors_total.isna()').head(7))
# Out:
# 5.0     5779
# 9.0     3757
# 16.0    1373
# 12.0    1361
# 4.0     1195
# 10.0    1173
# 25.0    1073
# 6.0      907
# 17.0     833
# 3.0      667
# 7.0      584
# 14.0     552
# 18.0     505
# 24.0     469
# 8.0      386
# 2.0      382
# 15.0     365
# 23.0     352
# 19.0     339
# 22.0     286
# 20.0     271
# 13.0     229
# 11.0     203
# 27.0     164
# 21.0     158
# 26.0     124
# 1.0       25
# 35.0      24
# 28.0      21
# 36.0       3
# 34.0       1
# 60.0       1
# 29.0       1
# 33.0       1
# 52.0       1
# Name: floors_total, dtype: int64
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 186             12    11640000       65.20           2018-10-02      2
# 237              4     2438033       28.10           2016-11-23      1
# 457              4     9788348       70.80           2015-08-01      2
# 671              4     6051191       93.60           2017-04-06      3
# ...

# %% [markdown]
# Заполним пропуски в зависимости от столбца "floor" по такому плану(поскольку строк всего 86, то можно их заполнить любыми значениями, невыбивающимися из большинства. И на результат это мало повлияет):
#
# * если значение floor 1-5 то это 5-ти этажка (так как 5 и 9 этажки самые распространенные)
# * если значение floor 6-9 то это 9-ти этажка (так как 5 и 9 этажки самые распространенные)
# * все что выше будем - приравняем floors_total к (floor-1) (так как если приравнять к первому или последнему это может повлиять на последующий анализ, пусть это будет не тот и не другой)

# %%
flats_sales_data.loc[flats_sales_data.query('floors_total.isna() and 1<=floor<=5').index, 'floors_total'] = 5
flats_sales_data.loc[flats_sales_data.query('floors_total.isna() and 6<=floor<=9').index, 'floors_total'] = 9
flats_sales_data.loc[flats_sales_data.query('floors_total.isna() and floor>9').index, 'floors_total'] = flats_sales_data['floor']-1
print('Строки с пропусками', flats_sales_data.query('floors_total.isna()'))
print(flats_sales_data['floors_total'].value_counts().head(7))
# Out:
# ---------------------------------------------------------------------------
# NumExprClobberingError                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13196\1761530671.py in <module>
# ----> 1 flats_sales_data.loc[flats_sales_data.query('floors_total.isna() and 1<=floor<=5').index, 'floors_total'] = 5
#       2 flats_sales_data.loc[flats_sales_data.query('floors_total.isna() and 6<=floor<=9').index, 'floors_total'] = 9
#       3 flats_sales_data.loc[flats_sales_data.query('floors_total.isna() and floor>9').index, 'floors_total'] = flats_sales_data['floor']-1
#       4 print('Строки с пропусками', flats_sales_data.query('floors_total.isna()'))
#       5 print(flats_sales_data['floors_total'].value_counts().head(7))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    4109         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4110         kwargs["target"] = None
# ...

# %% [markdown]
# И наконец поменяем тип на int

# %%
flats_sales_data['floors_total'] = flats_sales_data['floors_total'].astype('int')
print(f'Длина всего Data = {len(flats_sales_data)} // Длина заполненого floors_total = \
{flats_sales_data["floors_total"].count()} // Тип = {flats_sales_data["floors_total"].dtype}')

# %% [markdown]
# #### Столбец "living_area" и 13! Столбец "kitchen_area"

# %% [markdown]
# living_area - 21796 non-null float64 ---> !па / 8% пропусков - довольно много, надо проанализировать
# kitchen_area - 21421 non-null float64 ---> !па / 9% пропусков - довольно много, надо проанализировать

# %% [markdown]
# Надо прояснить следующие моменты. В общепринятом понимании Общая площадь квартиры = Кухня + Жилая + Нежилая. Балкон в площадь не входит(если это не лоджия). В квартирах-студиях Общая = Жилая + Нежилая. Аппартаменты = Квартира

# %% [markdown]
# Сначала заполним (с учетом среднего значения доли жилой площади к общей) "living_area" в студиях (если требуется)

# %%
print("Студий Всего",len(flats_sales_data.loc[flats_sales_data['studio']==True]))
print()
print("Студий с заполненными значениями", flats_sales_data.loc[flats_sales_data['studio']==True, 'living_area'].describe())
print(flats_sales_data['studio'].value_counts())

# %% [markdown]
# Присутствуют слишком маленькие жилые площади min=2, непорядок. Скорее всего это произошло, потому что не был дописан 0. Разберемся подробнее:

# %%
graf = pd.DataFrame(columns=['xd','yd']) # [Вся_площадь, Жилая]
graf['yd'] = flats_sales_data.loc[(flats_sales_data['living_area'].isna() == False) & (flats_sales_data['studio']==True), 'living_area']
graf['xd'] = flats_sales_data.loc[(flats_sales_data['living_area'].isna() == False) & (flats_sales_data['studio']==True), 'total_area']
print(graf)

graf.plot(y='yd', x='xd', style=".", figsize=(18,6), grid=True);

# %% [markdown]
# Видно, что есть неадекватные значения, где общая площадь меньше жилой или жилая совсем мала. Рассмотрим поближе

# %%
graf.plot(y='yd', x='xd', style=".", figsize=(16,4), grid=True, xlim=(0,30));

# %% [markdown]
# На этом графике нет значений где общая площадь меньше жилой (похоже иногда графика показывает не точно). Есть пара слишком маденьких значений жилой площади. Скорее всего это получилось из-за того , что не поставили 1 в разряде десятков. Исправим эти значения прибавив к ним 10

# %%
index_list = flats_sales_data.loc[(flats_sales_data['living_area']<10) & (flats_sales_data['studio']==True), ['living_area', 'total_area']].index
print(flats_sales_data.loc[index_list, ['living_area', 'total_area']])
flats_sales_data.loc[(flats_sales_data['living_area']<10) & (flats_sales_data['studio']==True), 'living_area'] +=10 # Прибавляем 10
print(flats_sales_data.loc[index_list, ['living_area', 'total_area']])

# %% [markdown]
# Исправили. Теперь в студиях значения жилой площади адекватны
#
# Теперь заполним пропуски в студиях (жилые) в соответствии со средним значением доли жилой к общей

# %%
print("Кол-во студий со значением =", flats_sales_data.loc[(flats_sales_data['living_area'].isna() == False) & (flats_sales_data['studio']==True), \
        'living_area'].count(), " // Кол-во студий всего =", flats_sales_data.loc[flats_sales_data['studio']==True, 'total_area'].count())
print()
part_live_in_studio = flats_sales_data.loc[flats_sales_data['studio']==True, 'living_area'] / flats_sales_data.loc[flats_sales_data['studio']==True, 'total_area']
print(part_live_in_studio.head())
print()

# Средняя доля жилой в студиях
part_live_in_studio = part_live_in_studio.dropna().mean() # Удаляем строки с NaN и считаем среднее
print("Средняя доля жилой площади в студии =", part_live_in_studio)
print()

# Меняем значение жилой в студии на = доля*общую
flats_sales_data.loc[(flats_sales_data['living_area'].isna() == True) & (flats_sales_data['studio']==True), 'living_area'] = \
    flats_sales_data.loc[(flats_sales_data['living_area'].isna() == True) & (flats_sales_data['studio']==True), 'total_area'] * part_live_in_studio

# %%
# Проверим
print("Кол-во студий со значением =", flats_sales_data.loc[(flats_sales_data['living_area'].isna() == False) & (flats_sales_data['studio']==True), \
        'living_area'].count(), " // Кол-во студий всего =", len(flats_sales_data.loc[flats_sales_data['studio']==True]))

display(flats_sales_data.query('studio==True'))

# %% [markdown]
# Теперь заполним пропуски медианными значениями "living_area" в зависимости от "total_area", логично предположить (и жизненный опыт это подтвердит) что, чем больше общая площадь, тем больше площадь жилая и кухни, и тем больше доля другой(нежилой площади). Выведем диаграмму доли"living_area" в "total_area" в зависимости от "total_area"(благо этот столбец мы заполнили) и на будущее параллельно сделаем тоже для "kitchen_area". Только исключим из анализа квартиры студии (так как мы их обработали)
#
# ! Будем рассматривать 3 площади вместе (так как они взаимосвязаны) - общая, жилая, кухня
#
# Заполним пропуски площади "kitchen_area", потом "living_area", а затем еще проверим их сумму(она не должна быть больше общей площади), и скорректируем если что.

# %%
display(flats_sales_data.loc[:,['total_area', 'living_area', 'kitchen_area']])

# %%
print('-=Все значения рассчитываются, исключая студии=-')
print()
print("Кол-во квартир всего =", len(flats_sales_data.loc[flats_sales_data['studio']==False]))

print("Кол-во квартир со значением в жилой =", flats_sales_data.loc[(flats_sales_data['living_area'].isna() == False) & \
                                                        (flats_sales_data['studio']==False), 'living_area'].count(), )

print("Кол-во квартир со значением в кухне =", flats_sales_data.loc[(flats_sales_data['kitchen_area'].isna() == False) & \
                                                        (flats_sales_data['studio']==False), 'kitchen_area'].count(), )

# %% [markdown]
# Для удобства сделаем отдельный ДатаФрейм (без Студий)- Здесь будут оригиналы (на всякий случай; для сравнения и вывода графиков)

# %%
sq = pd.DataFrame(columns=['all','liv', 'kit']) # [Вся_площадь, Жилая, Кухня] - Здесь будут оригиналы
sq['all'] = flats_sales_data.loc[(flats_sales_data['total_area'].isna() == False) & (flats_sales_data['studio']==False), 'total_area']
sq['liv'] = flats_sales_data.loc[(flats_sales_data['living_area'].isna() == False) & (flats_sales_data['studio']==False), 'living_area']
sq['kit'] = flats_sales_data.loc[(flats_sales_data['kitchen_area'].isna() == False) & (flats_sales_data['studio']==False), 'kitchen_area']
print(sq)
print()

print("проверка совпадает ли с оригиналом")
print(flats_sales_data.loc[flats_sales_data['studio']==False, ['total_area', 'living_area', 'kitchen_area']])

# %% [markdown]
# Рассчитаем Медианы и Средние доли кухни и жилой в общей площади а также добавим долю оставшейся площади (part_other)

# %%
part_kit = sq['kit'] / sq['all']
part_kit_median = part_kit.dropna().median()
part_kit_mean = part_kit.dropna().mean()
print("part_kit_median =", part_kit_median, "// part_kit_mean =", part_kit_mean)
print()
part_liv = sq['liv'] / sq['all']
part_liv_median = part_liv.dropna().median()
part_liv_mean = part_liv.dropna().mean()
print("part_liv_median =", part_liv_median, "// part_liv_mean =", part_liv_mean)

# %% [markdown]
# Медиана и среднее мало отличаются. Выберем медиану для дальнейших действий

# %%
part_kit = part_kit_median
part_liv = part_liv_median
part_other = 1 - part_liv_median - part_kit_median
print('part_other =',part_other)

# %% [markdown]
# Заполним пропуски в столбцах кухня и жилая значениями = (медиана x общую)
# Начнем с кухни

# %%
ind_nan_kit = flats_sales_data.loc[(flats_sales_data['kitchen_area'].isna() == True) & (flats_sales_data['studio']==False)].index # Индексы где пропуски в значениях 'kitchen_area'
flats_sales_data.loc[ind_nan_kit, 'kitchen_area'] = part_kit * flats_sales_data.loc[ind_nan_kit, 'total_area']

# %%
print(flats_sales_data['kitchen_area'].describe())

# %%
ind_nan_liv = flats_sales_data.loc[(flats_sales_data['living_area'].isna() == True) & (flats_sales_data['studio']==False)].index # Индексы где пропуски в значениях 'living_area'
flats_sales_data.loc[ind_nan_liv, 'living_area'] = part_liv * flats_sales_data.loc[ind_nan_liv, 'total_area']

# %%
print(flats_sales_data['living_area'].describe())

# %% [markdown]
# Видно что присутствуют слишком маленькие значения как в кухнях (min = 1,3), так и в жилых (min = 2)

# %% [markdown]
# **Разберемся с некорректными значениями в кухнях.**

# %%
sq['kit'].describe()
sq.plot(y='kit', x='all', style=".", figsize=(18,6), grid=True);
plt.show
sq.plot(y='kit', x='all', kind='scatter', figsize=(18,6), grid=True, xlim=(0, 200), ylim=(0, 60));

# %% [markdown]
# Видно что есть слишком маленькие и слишком большие значения (их мало) кухни. Установим разумные пределы кухни (min_kit = 3 и max_kit = 40) и все что выходит за пределы заменим на предельные значения соответственно.

# %%
min_kit = 3
max_kit = 40

flats_sales_data.loc[(flats_sales_data['kitchen_area']<min_kit) & (flats_sales_data['studio']==False), 'kitchen_area'] = min_kit
flats_sales_data.loc[(flats_sales_data['kitchen_area']>max_kit) & (flats_sales_data['studio']==False), 'kitchen_area'] = max_kit

flats_sales_data.loc[(flats_sales_data['studio']==False),'kitchen_area'].describe()

# %% [markdown]
# Посмотрим есть ли очень маленькие и большиие значения в жилой ('living_area')

# %%
sq['liv'].describe()
sq.plot(y='liv', x='all', style=".", figsize=(18,6), grid=True);
plt.show
sq.plot(y='liv', x='all', kind='scatter', figsize=(18,6), grid=True, xlim=(0, 150), ylim=(0, 150));

# %%
print('ОБЩАЯ ПЛОЩАДЬ :')
flats_sales_data.loc[(flats_sales_data['studio']==False),'total_area'].describe()

# %% [markdown]
# Видно что есть значения при которых жилая площадь слишком мала по сравнению с общей при медиане доли - part_liv_median = 0.567 (56,7%)
# Малыми площадями будем считать если они меньше 30% от общей
# Заполним эти значения 40% (~середина между общ-56,7% и нежил-26.6%) от общей площадей.
# Также установим минимальный размер жилой площади = 5 кв.м (уж меньше некуда)
# И еще сделаем корректировку для квартир с общей площадью < 140 кв.м (там где площадь больше чем 140, там более менее сносные значения, и в них сильно будут отличаться от средней пропорции жилой/нежилой/кухни)

# %%
ind_lst = flats_sales_data.loc[ (flats_sales_data['living_area'] < flats_sales_data['total_area']*0.3) & (flats_sales_data['total_area']<140) & (flats_sales_data['studio']==False) ].index
flats_sales_data.loc[ind_lst, 'living_area'] = flats_sales_data.loc[ind_lst, 'total_area'] * 0.4

# %%
# Проверим что получилось
print(flats_sales_data['living_area'].describe())
flats_sales_data[(flats_sales_data['studio']==False)].plot(
    y='living_area', x='total_area', kind='scatter', figsize=(18,6), grid=True, xlim=(0, 150), ylim=(0, 150));

# %% [markdown]
# Теперь проверим корректность проделанного. Сверим оставшиеся помещения - другие (нежилые = общая - жилая - кухня) с разумным минимумом равным 4 кв.м (коридор=1,5 + (туалет+ванна)=2,5 = 4). Итого в самой маленькой квартире 12кв.м = 3кух + 5жил + 4нежил Минимум 7,37 - по минимуму проходим. (зато по общей площади теперь переполнение)
#
# Вспомним и запишем минимумы:
# - kit_min = 3
# - liv_min = 5
# - noliv_min = 4

# %%
kit_min = 3
liv_min = 5
noliv_min = 4


# Индексы где другая (нежилая) площадь меньше noliv_min
ind_small_noliv = flats_sales_data.loc[ (flats_sales_data['studio']==False) & (((flats_sales_data['total_area'] - flats_sales_data['living_area'] - \
                                                        flats_sales_data['kitchen_area']) < noliv_min) )].index
display(flats_sales_data.loc[ind_small_noliv,['total_area', 'living_area','kitchen_area']])

# Выводим значения со слишком маленькой нежилой площадья
square_table = flats_sales_data.loc[ind_small_noliv,'total_area'] - flats_sales_data.loc[ind_small_noliv,'living_area'] - \
flats_sales_data.loc[ind_small_noliv,'kitchen_area']
print(square_table)
square_table.describe()

# %% [markdown]
# Даже присутствуют отрицательные значения. Восполним остальную площадь до минимума (5кв.м) за счет жилой и кухни. Будем урезать каждую на 2%, пока пока не будут достигнуты минимумы или другая(нежилая) станет около 5 кв.м
# Напишем функцию cut_square(ind) которая будет принимать индекс некорректной строки и "подрезать" площади, если удачно возвращает 0 если нет ind

# %%
# -------ФУНКЦИЯ---------------------  
def cut_square(ind):
    kit = flats_sales_data.loc[ind, 'kitchen_area']
    liv = flats_sales_data.loc[ind, 'living_area']
    tot = flats_sales_data.loc[ind, 'total_area']
    kit_min = 3
    liv_min = 5
    noliv_min = 4
    cut = 0.98 # Коэффициент на который надо умножить чтобы обрезать значение на 2%
    while noliv_min >= tot - kit - liv:
        if liv > liv_min:
            liv = liv * cut  # Обрезаем на 2% жилую
        if kit > kit_min:
            kit = kit * cut  # Обрезаем на 2% кухню
        
    noliv = tot - kit - liv    
    flats_sales_data.loc[ind, 'kitchen_area'] = kit
    flats_sales_data.loc[ind, 'living_area'] = liv
    return [ind, tot, liv, kit, noliv] # Соберем
    
# ------------------------------------    

# i = []
c=0 # Счетчик замен
for index in ind_small_noliv:
#     i.append(cut_square(index))
    print(flats_sales_data.loc[index,['total_area', 'living_area', 'kitchen_area']])
    print(cut_square(index))
    print(flats_sales_data.loc[index,['total_area', 'living_area', 'kitchen_area']])
#     input()
    print()
    c+=1
print("Произведенено замен =",c)

# %%
square_table = flats_sales_data.loc[ind_small_noliv,'total_area'] - flats_sales_data.loc[ind_small_noliv,'living_area'] - \
flats_sales_data.loc[ind_small_noliv,'kitchen_area']
print(square_table)
print(square_table.describe())
flats_sales_data.loc[:,['total_area','living_area','kitchen_area']].describe()

# %% [markdown]
# Вроде все получилось, немножко вылезли некоторые значения 'living_area', 'kitchen_area' за 5 и 3 кв.м, это получилось из-за того, что значения при корректировке были чуть выше kit_min = 3 / liv_min = 5 и -2% получим что имеем. Можно было отрезать не по 2%, а скажем по 0,1%, тогда отклонение было бы меньше. Полученый результат вполне допустим.
#
# Теперь для наглядности округлим значения 'living_area', 'kitchen_area' до одной десятой

# %%
print(flats_sales_data[['living_area', 'kitchen_area']].head(7))
flats_sales_data[['living_area', 'kitchen_area']] = round(flats_sales_data[['living_area', 'kitchen_area']],1)
print(flats_sales_data[['living_area', 'kitchen_area']].head(7))

# %%
flats_sales_data.info()

# %% [markdown]
# ВЫВОД: 'living_area', 'kitchen_area' - готовы, но надо помнить что , в строках где квартиры-студии в колонке кухни будет стоять NaN (149 строк). В вышеприведенном отчете это видно

# %% [markdown]
# #### Столбец "floor"

# %% [markdown]
# Пропусков нет. Проверим корректность значений

# %%
print(flats_sales_data['floor'].value_counts())

# %% [markdown]
# ВЫВОД: Всё в порядке

# %% [markdown]
# #### Столбец "is_apartment"

# %% [markdown]
# Проверим пропуски скорее всего это "не аппартаменты" (так как аппартаменты это редкость) и заполним "0". Поменяем тип на bool, и забудем про этот столбец, так как он не нужен для выполнения задачи.

# %%
print(flats_sales_data['is_apartment'].value_counts(), " // Тип = ", flats_sales_data['is_apartment'].dtype)

# %%
flats_sales_data.loc[flats_sales_data['is_apartment'] != True, 'is_apartment'] = False
flats_sales_data['is_apartment'] = flats_sales_data['is_apartment'].astype('bool')
print(flats_sales_data['is_apartment'].value_counts(), " // Тип = ", flats_sales_data['is_apartment'].dtype)

# %% [markdown]
# ВЫВОД: Всё в порядке

# %% [markdown]
# #### Столбец "studio"

# %% [markdown]
# Корректный столбец. Проверим значения на всякий случай.

# %%
print(flats_sales_data['studio'].value_counts(), " // Тип = ", flats_sales_data['studio'].dtype)

# %%
display(flats_sales_data.loc[flats_sales_data['studio']==True, ['total_area', 'living_area', 'kitchen_area']])
print('Для проверки - посчитаем сколько Студий без кухни(должно быть 149) Расчетное значение =',flats_sales_data.loc[flats_sales_data['studio']==True]['kitchen_area'].isna().sum())

# %% [markdown]
# ВЫВОД: Здесь всё в порядке!

# %% [markdown]
# #### Столбец "open_plan"

# %% [markdown]
# Корректный столбец. Проверим значения на всякий случай.

# %%
print(flats_sales_data['open_plan'].value_counts(), " // Тип = ", flats_sales_data['open_plan'].dtype)

# %% [markdown]
# ВЫВОД: Здесь всё в порядке!

# %% [markdown]
# #### Столбец "kitchen_area" - Скорректирован со столбцом 8."living_area"

# %% [markdown]
# (9% пропусков - довольно много, надо проанализировать и заполнить)

# %% [markdown]
# #### Столбец "balcony"

# %% [markdown]
# Проанализируем и скорее всего заполним пропуски "1"(т.к. логично что (и по статистике) у большинства 1 балкон). И забудем про этот столбец, так как он не нужен для выполнения задачи.

# %%
print(flats_sales_data['balcony'].value_counts())
print()
print("Кол-во NaN =",flats_sales_data['balcony'].isna().sum())

# %%
flats_sales_data['balcony'] = flats_sales_data['balcony'].fillna(1)
print(flats_sales_data['balcony'].value_counts())
print("Кол-во NaN =",flats_sales_data['balcony'].isna().sum())

# %% [markdown]
# Поменяем тип напоследок

# %%
flats_sales_data['balcony'].dtype
flats_sales_data['balcony'] = flats_sales_data['balcony'].astype(int)
flats_sales_data['balcony'].dtype

# %% [markdown]
# ВЫВОД: Все получилось, NaN поменяли на 1 (так больше похоже на правду) и поменяли тип на int

# %% [markdown]
# #### Столбец "locality_name"

# %%
print(flats_sales_data['locality_name'].value_counts())
print()
print("Кол-во пропущеных значений", flats_sales_data['locality_name'].isna().sum())
print()
display(flats_sales_data['locality_name'].sort_values().unique())

# %% [markdown]
# Всего 49 пропусков ( 0,2% ). Видно, что слово посёлок написано в 2 вариантах с "ё" и "е". Cначала разберемся с поселком

# %%
# Чтобы не мучиться, заменим все "ё" на "е" во всем столбце 'locality_name'
import re
i = 0 # счетчик строк где Ё и ё
for ind_str in flats_sales_data.loc[(flats_sales_data['locality_name'].isna()==False),'locality_name'].index:    
    loc_str = flats_sales_data.loc[ind_str, 'locality_name']
    if ('ё' or 'Ё') in loc_str:
        i+=1
        loc_str = re.sub('ё', 'е', loc_str)
        loc_str = re.sub('Ё', 'Е', loc_str)
    flats_sales_data.loc[ind_str, 'locality_name'] = loc_str
print()
print("Кол-во строк где произведена замена =", i)

# %%
print(flats_sales_data['locality_name'].value_counts())

# %% [markdown]
# Замену произвели.
# Проверим наличие одних и тех же имен населенных пунктов, записанных по-разному (сравним их леммы). Изначально имен 330

# %%
from pymystem3 import Mystem 
m = Mystem()

#   Создадим и заполним ДатаФрейм где 3 столбца : 
#   'original' - оригинал строки, 'lemm' - Лемматизированная строка, 
#   'name' - лемматизированное имя населенного пункта
loc_df = pd.DataFrame(columns=['original', 'lemm', 'name'])
loc_df['original'] = flats_sales_data.loc[(flats_sales_data['locality_name'].isna()==False),'locality_name'].sort_values(na_position='last').unique()

for ind in loc_df.index:
    lem_str = m.lemmatize(loc_df.loc[ind, 'original'])
    loc_df.loc[ind, 'lemm'] = lem_str
    loc_df.loc[ind, 'name'] = lem_str[-2]

display(loc_df)

print(loc_df['lemm'].value_counts())

# %% [markdown]
# Видно, что [поселок, , саперный, \n] повторяется 2 раза. Выясним "original" названия

# %%
display(loc_df[loc_df['name']=='саперный'])

# %% [markdown]
# Можно проверить по расстоянию от центра или с помощь других расстояний, но лучше воспользуемся Википедией:
# - Сапёрное - https://ru.wikipedia.org/wiki/%D0%A1%D0%B0%D0%BF%D1%91%D1%80%D0%BD%D0%BE%D0%B5
# - Сапёрный - https://ru.wikipedia.org/wiki/%D0%A1%D0%B0%D0%BF%D1%91%D1%80%D0%BD%D1%8B%D0%B9_(%D0%A1%D0%B0%D0%BD%D0%BA%D1%82-%D0%9F%D0%B5%D1%82%D0%B5%D1%80%D0%B1%D1%83%D1%80%D0%B3)
#
#     Это 2 разных населенных пункта, замен здесь делать не будем
#
# Теперь посмторим имена населенных пунктов

# %%
display(flats_sales_data.loc[flats_sales_data['locality_name']=='поселок Саперный'])
display(flats_sales_data.loc[flats_sales_data['locality_name']=='поселок Саперное'])

# %% [markdown]
# На всякий случай проверили и в data. Столбцы с расстояниями где "поселок Саперное" пусты поэтому сравнить не получится. Будем считать , что это всетаки разные населенные пункты

# %%
print(loc_df['name'].value_counts())

# %%
rep_name = loc_df['name'].value_counts() # Series где запишем что и сколько повторяется

for name in rep_name.index:
    if rep_name[name] == 1:
        break
    print(loc_df[loc_df['name']==name]['original'])

# %% [markdown]
# В Википедиии сказано, что "... В Ленинградской области России городскими посёлками называются все посёлки городского типа..." (да и область как мы видим Ленинградская)
# https://ru.wikipedia.org/wiki/%D0%9F%D0%BE%D1%81%D1%91%D0%BB%D0%BE%D0%BA_%D0%B3%D0%BE%D1%80%D0%BE%D0%B4%D1%81%D0%BA%D0%BE%D0%B3%D0%BE_%D1%82%D0%B8%D0%BF%D0%B0
#
# Исправим "городской поселок" на "поселок городского типа"

# %%
# Заменим все 'городской поселок' на 'поселок городского типа' в loc_df столбце 'original'

i = 0 # счетчик строк где 'городской поселок'
# for ind_str in loc_df.loc[(loc_df['locality_name']!=np.nan),'locality_name'].index:
for ind_str in loc_df.loc[(loc_df['original'].isna()==False),'original'].index:    
    loc_str = loc_df.loc[ind_str, 'original']
    if 'городской поселок' in loc_str:
        print(loc_str)
        loc_str = re.sub('городской поселок', 'поселок городского типа', loc_str)
        i+=1
#         print(loc_str)
        loc_df.loc[ind_str, 'original'] = loc_str
        print(loc_df.loc[ind_str, 'original'])
print("Кол-во строк где произведена замена =", i)

# %% [markdown]
# Чтобы не мучиться, заменим все 'городской поселок' на 'поселок городского типа' во всем столбце 'locality_name' в flats_sales_data

# %%
# Чтобы не мучиться, заменим все 'городской поселок' на 'поселок городского типа' во всем data столбце 'locality_name'

i = 0 # счетчик строк где 'городской поселок'
# for ind_str in data.loc[(data['locality_name']!=np.nan),'locality_name'].index:
for ind_str in flats_sales_data.loc[(flats_sales_data['locality_name'].isna()==False),'locality_name'].index:    
    loc_str = flats_sales_data.loc[ind_str, 'locality_name']
    if 'городской поселок' in loc_str:
        print(loc_str)
        loc_str = re.sub('городской поселок', 'поселок городского типа', loc_str)
        i+=1
#         print(loc_str)
        flats_sales_data.loc[ind_str, 'locality_name'] = loc_str
        print(flats_sales_data.loc[ind_str, 'locality_name'])
print("Кол-во строк где произведена замена =", i)

# %% [markdown]
# И переинициализируем таблицу loc_df

# %%
loc_df = pd.DataFrame(columns=['original', 'lemm', 'name'], data=[])
loc_df['original'] = flats_sales_data.loc[(flats_sales_data['locality_name'].isna()==False),'locality_name'].sort_values().unique()
for ind in loc_df.index:
    lem_str = m.lemmatize(loc_df.loc[ind, 'original'])
    loc_df.loc[ind, 'lemm'] = lem_str
    loc_df.loc[ind, 'name'] = lem_str[-2]
display(loc_df.tail())

# %%
print(loc_df['name'].value_counts().head(30))

rep_name = loc_df['name'].value_counts() # Series где запишем что и сколько повторяется

for name in rep_name.index:
    if rep_name[name] == 1:
        break
    print(loc_df[loc_df['name']==name]['original'])

# %% [markdown]
# * 233 поселок Рябово
# * 288 поселок городского типа Рябово
#
# * 301 поселок при железнодорожной станции Вещево
# * 303 поселок станции Вещево
#
# Есть и другие
#
# Возможно это одни и те же населенные пункты. Чтобы проверить добавим в loc_df столбцы "dist_centre" с расстоянием до центра и другие расстояния 'airports_nearest', 'parks_nearest', 'ponds_nearest'

# %%
for ind in loc_df.index:
    loc_df.loc[ind, 'dist_centre'] = flats_sales_data.loc[ flats_sales_data['locality_name']==loc_df.loc[ind, 'original'], 'cityCenters_nearest' ].mean()
    loc_df.loc[ind, 'dist_airp'] = flats_sales_data.loc[ flats_sales_data['locality_name']==loc_df.loc[ind, 'original'], 'airports_nearest' ].mean()
    loc_df.loc[ind, 'dist_park'] = flats_sales_data.loc[ flats_sales_data['locality_name']==loc_df.loc[ind, 'original'], 'parks_nearest' ].mean()
    loc_df.loc[ind, 'dist_pond'] = flats_sales_data.loc[ flats_sales_data['locality_name']==loc_df.loc[ind, 'original'], 'ponds_nearest' ].mean()
display(loc_df.head(20))

# %% [markdown]
# Теперь попробуем разобраться с пропусками. Надо изучить расстояния которые даны, чтобы определить что это за населенный пункт

# %%
nan_loc_df = flats_sales_data.loc[flats_sales_data['locality_name'].isna()==True, ['cityCenters_nearest', 'airports_nearest', \
                                                           'parks_nearest', 'ponds_nearest']]
nan_loc_df.head()

# %%
# Удалим пропуски в 2 столбцах
nan_loc_df = nan_loc_df.dropna(subset=['cityCenters_nearest', 'airports_nearest'])
nan_loc_df['loc_list'] = np.nan
nan_loc_df

# %% [markdown]
# **ВЫВОД: Проделали огромную работу, исправили названия населенных пунктов, удалили всего 11 строк, менее 0,1% от всего числа. Столбец готов**

# %% [markdown]
# #### Столбец "airports_nearest"

# %% [markdown]
# Проанализируем, если не получится быстро заполнить, то можно оставить как есть. Поменяем тип на int

# %% [markdown]
# **Надо отметить , что количество значений в столбцах с 2 расстояниями и 2 некоторыми другими почти одинаковое - 18181:**
#
# * airports_nearest 18157 non-null float64
# * cityCenters_nearest 18180 non-null float64
# * parks_around3000 18181 non-null float64
# * parks_nearest 8079 non-null float64
# * ponds_around3000 18181 non-null float64
# * ponds_nearest 9110 non-null float64
#
# **Для заполнения пропусков в столбцах с расстояниями будем использовать схожий алгоритм - заполнять их в зависимости от населенного пункта**

# %%
descr_numeric('airports_nearest')

# %% [markdown]
# Выбросов вроде нет зато есть нули, надо рассмотреть подробнее

# %%
flats_sales_data['airports_nearest'].hist(range=(0,1000),bins=50)

# %%
flats_sales_data[flats_sales_data['airports_nearest']<50]

# %% [markdown]
# Всего одна строка, это Санкт-Петербург, 0 заменили на Nan и обработаем вместе с остальными пропусками

# %%
flats_sales_data.loc[21003, 'airports_nearest'] = np.nan
flats_sales_data.loc[21003]

# %% [markdown]
# Все пропуски заполним медианами значений airports_nearest (если оно будет не NaN) из других строк где совпадает locality_name

# %%
# loc_median - здесь сохрним медианы расстояний по населенным пунктам

print('Медианы расстояний airports_nearest в locality_name : ')
loc_median = flats_sales_data.groupby('locality_name')['airports_nearest'].median().sort_values()
loc_median = loc_median.dropna()
display(loc_median.head(15))

# Функция для присваивания пропуску значения медианы
def med_insert(loc_dist):
    if loc_dist not in loc_median:
        return np.nan
    return loc_median[loc_dist]


print('Проверка работы med_insert: поселок Понтонный - ', med_insert('поселок Понтонный')) 
print('Проверка работы med_insert: поселок Усть-Ижора - ', med_insert('поселок Усть-Ижора'))

# %%
# Выборка для проверки
print('Всего пропущенных значений в столбце =', flats_sales_data['airports_nearest'].isna().sum())
test_ind = flats_sales_data.loc[(flats_sales_data['locality_name']=='Санкт-Петербург') & (flats_sales_data['airports_nearest'].isna()==True)].index
print("Всего пропущенных значений в Санкт-Петербург =", len(test_ind))
display(flats_sales_data.loc[test_ind,['locality_name','airports_nearest']].head(12))

# %%
# ДЕЛАЕМ ЗАМЕНУ
flats_sales_data.loc[flats_sales_data['airports_nearest'].isna()==True, 'airports_nearest'] = flats_sales_data['locality_name'].apply(med_insert)

# %% [markdown]
# Проверим сколько осталось пропусков и найдем медианцу столбца

# %%
print("Кол-во пропусков оставшихся =", flats_sales_data['airports_nearest'].isna().sum())

# %%
# print('Тип до замены', flats_sales_data['airports_nearest'].dtype)
# flats_sales_data['airports_nearest'] = data['airports_nearest'].astype(int)
# print('Тип после замены', flats_sales_data['airports_nearest'].dtype)

# %% [markdown]
# Поменять тип столбца, так как есть пропуски, не получаеться
#
# **ВЫВОД: Осталось очень много пропусков. По-скольку для поставленных целей столбец не нужен - оставим как есть.**

# %% [markdown]
# #### Столбец "cityCenters_nearest"

# %%
 descr_numeric('cityCenters_nearest')

# %%
flats_sales_data['cityCenters_nearest'].hist(figsize=(16,4), bins=100);

# %%
flats_sales_data['cityCenters_nearest'].hist(figsize=(16,4), bins=100, range=(0,3000))

# %% [markdown]
# Выбросов вроде нет, значения распределены равномерно
#
# **Займемся заполнением пропусков**
# Будем искать соответсткие в столбце (locality_name) название населённого пункта. Если населенный пункт в пропуске совпадает с другими где нет пропусков, то посчитаем среднее для тех где есть значение расстояние до центра

# %% [markdown]
# Все пропуски заполним медианами значений cityCenters_nearest (если оно будет не NaN) из других строк где совпадает locality_name

# %%
# loc_median - здесь сохрним медианы расстояний по населенным пунктам

print('Медианы расстояний cityCenters_nearest в locality_name : ')
loc_median = flats_sales_data.groupby('locality_name')['cityCenters_nearest'].median().sort_values()
loc_median = loc_median.dropna()
display(loc_median.head(15))

# Функция для присваивания пропуску значения медианы
def med_insert(loc_dist):
    if loc_dist not in loc_median:
        return np.nan
    return loc_median[loc_dist]


print('Проверка работы med_insert: поселок Песочный - ', med_insert('поселок Песочный')) 
print('Проверка работы med_insert: поселок Петро-Славянка - ', med_insert('поселок Петро-Славянка'))

# %%
# Выборка для проверки
print('Всего пропущенных значений в столбце =', flats_sales_data['cityCenters_nearest'].isna().sum())
test_ind = flats_sales_data.loc[(flats_sales_data['locality_name']=='Санкт-Петербург') & (flats_sales_data['cityCenters_nearest'].isna()==True)].index
print("Всего пропущенных значений в Санкт-Петербург =", len(test_ind))
display(flats_sales_data.loc[test_ind,['locality_name','cityCenters_nearest']].head(12))

# %%
# ДЕЛАЕМ ЗАМЕНУ
flats_sales_data.loc[flats_sales_data['cityCenters_nearest'].isna()==True, 'cityCenters_nearest'] = flats_sales_data['locality_name'].apply(med_insert)

# %%
# ПРОВЕРЯЕМ
display(flats_sales_data.loc[test_ind,['locality_name','cityCenters_nearest']].head(12))

# %% [markdown]
# Проверим сколько осталось пропусков и найдем медианцу столбца

# %%
print("Кол-во пропусков оставшихся =", flats_sales_data['cityCenters_nearest'].isna().sum())

# %% [markdown]
# Всего пропущенных значений было в столбце = 5508

# %%
print('итого было исправлено 5508 - 4862 =' , 5508 - 4862)

# %% [markdown]
# **Всего удалось заполнить 646 строк - очень мало**
#
# !! Очень много пропусков !!
#
# Вернемся к данным приведенным в начале обработки столбца 16.airports_nearest:
#
# * airports_nearest 18157 non-null float64
# * cityCenters_nearest 18180 non-null float64
# * parks_around3000 18181 non-null float64
# * parks_nearest 8079 non-null float64
# * ponds_around3000 18181 non-null float64
# * ponds_nearest 9110 non-null float64
#
# **У выделенных столбцов около 18181 значение. Проверим заполненные/пропущенные значения в одних и тех же строках?**

# %%
# заполненные

# matches_False = flats_sales_data.loc[(flats_sales_data['airports_nearest'].isna()==False) & (data['cityCenters_nearest'].isna()==False) & \
#          (flats_sales_data['parks_around3000'].isna()==False) & (data['ponds_around3000'].isna()==False),'locality_name'].count()

matches_False = flats_sales_data.query('airports_nearest.isna()==False and cityCenters_nearest.isna()==False and \
                                parks_around3000.isna()==False and ponds_around3000.isna()==False')

print('Количество строк в которых одномременно заполненны все 4 столбца =', matches_False['locality_name'].count())

# %%
# пропущенные

# matches_True = flats_sales_data.loc[(flats_sales_data['airports_nearest'].isna()==True) & (data['cityCenters_nearest'].isna()==True) & \
#          (flats_sales_data['parks_around3000'].isna()==True) & (data['ponds_around3000'].isna()==True),'locality_name'].count()

#---- !! matches_True - сохраним для баг-репорта ------------------------------------
matches_True = flats_sales_data.query('airports_nearest.isna()==True and cityCenters_nearest.isna()==True and \
                                parks_around3000.isna()==True and ponds_around3000.isna()==True')

print('Количество строк в которых одномременно НЕзаполненны все 4 столбца =', matches_True['locality_name'].count())

display(matches_True.groupby('locality_name')['locality_name'].count().sort_values().tail(15))

# %% [markdown]
# ВЫВОД: Оставшиеся пропущенные значения в столбце cityCenters_nearest заполнить не представляется возможным, так как если заполнить медианой или средней по всему столбцу это очень сильно может повлиять на исследовательский анализ и сильно исказить результаты и выводы. Поэтому оставим все как есть, и будем выполнять анализ с таким количеством пропусков.

# %% [markdown]
# p.s. В столбце airports_nearest мы наблюдали похожую картину, полагаю и в parks_around3000 и ponds_around3000 нас ждет похожая картина(благо они не представляют ценности для анализа). При таком совпадении можно сделать вывод, что пропущенные данные в этих столбцах были каким-то образом утеряны или скорее всего не внесены в таблицу, причем по конкретным пунктам - возможно прямо по каким-то областям (так как мы пробовали найти соответствие в пропущенных и заполненных населенных пунктах и его почти не было)! Данные для баг-репорта сохранимли в ДатаФрейм - matches_True

# %%
matches_True.head()

# %% [markdown]
# Переведем расстояние в км

# %%
flats_sales_data['cityCenters_nearest'] = round(flats_sales_data['cityCenters_nearest'] / 1000)
try:
    flats_sales_data['cityCenters_nearest'] =  М['cityCenters_nearest'].astype('Int32')
    print('cityCenters_nearest')
except:
    print('cityCenters_nearest Int32 type conversion fail')

# %% [markdown]
# #### Столбец "parks_around3000"

# %%
flats_sales_data['parks_around3000'].value_counts(dropna=False)

# %% [markdown]
# Поскольку видно, что значение 0 это большинство и логично, что при заполнениии если значение не проставлено, то оно равно 0,- заполним пропуски 0. (Так же учтем то, что этот столбец бесполезен для выполнения задачи не будем тратить время на него). И изменим тип на int

# %%
flats_sales_data['parks_around3000'] = flats_sales_data['parks_around3000'].fillna(0)
display(flats_sales_data['parks_around3000'].value_counts(dropna=False))
flats_sales_data['parks_around3000'] = flats_sales_data['parks_around3000'].astype(int)
print(flats_sales_data['parks_around3000'].dtype)

# %% [markdown]
# **ВЫВОД: Столбец корректен.**

# %% [markdown]
# #### Столбец "parks_nearest"

# %%
descr_numeric('parks_nearest')

# %%
flats_sales_data['parks_nearest'].hist(figsize=(16,4), bins=100, range=(0,100));

# %%
flats_sales_data['parks_nearest'].hist(figsize=(16,4), bins=100, range=(1000,3200));

# %% [markdown]
# Значения распределены равномерно. Большая часть меньше 3000. Удалять ничего небудем.
#
# Будем заполнять пропуски по аналогии со столбцом cityCenters_nearest и airports_nearest по соответствию населенному пункту

# %%
# loc_median - здесь сохрним медианы расстояний по населенным пунктам

print('Медианы расстояний parks_nearest в locality_name : ')
loc_median = flats_sales_data.groupby('locality_name')['parks_nearest'].median().sort_values()
loc_median = loc_median.dropna()
display(loc_median.head(15))

# Функция для присваивания пропуску значения медианы
def med_insert(loc_dist):
    if loc_dist not in loc_median:
        return np.nan
    return loc_median[loc_dist]


print('Проверка работы med_insert: Сестрорецк - ', med_insert('Сестрорецк')) 
print('Проверка работы med_insert: поселок Зеленогорск - ', med_insert('Зеленогорск'))

# %%
# Выборка для проверки
print('Всего пропущенных значений в столбце =', flats_sales_data['parks_nearest'].isna().sum())
test_ind = flats_sales_data.loc[(flats_sales_data['locality_name']=='Санкт-Петербург') & (flats_sales_data['parks_nearest'].isna()==True)].index
print("Всего пропущенных значений в Санкт-Петербург =", len(test_ind))
display(flats_sales_data.loc[test_ind,['locality_name','parks_nearest']].head(12))

# %%
# ДЕЛАЕМ ЗАМЕНУ
flats_sales_data.loc[flats_sales_data['parks_nearest'].isna()==True, 'parks_nearest'] = flats_sales_data['locality_name'].apply(med_insert)

# %%
# ПРОВЕРЯЕМ
display(flats_sales_data.loc[test_ind,['locality_name','parks_nearest']].head(12))

# %% [markdown]
# Проверим сколько осталось пропусков

# %%
print("Кол-во пропусков оставшихся =", flats_sales_data['parks_nearest'].isna().sum())

# %% [markdown]
# ВЫВОД: было пропусков 15569 осталось 5996 - большую часть значений заполнили, теперь со значениями около 18 тысяч.
# Остальные не заполняем по аналогии с другими столбцами с расстояниями

# %% [markdown]
# #### Столбец "ponds_around3000"

# %%
flats_sales_data['ponds_around3000'].value_counts(dropna=False)

# %% [markdown]
# **Все сделаем по аналогии состолбцом parks_around3000**

# %%
flats_sales_data['ponds_around3000'] = flats_sales_data['ponds_around3000'].fillna(0)
display(flats_sales_data['ponds_around3000'].value_counts(dropna=False))
flats_sales_data['ponds_around3000'] = flats_sales_data['ponds_around3000'].astype(int)
print(flats_sales_data['ponds_around3000'].dtype)

# %% [markdown]
# ВЫВОД: Столбец корректен.

# %% [markdown]
# #### 21. Столбец "ponds_nearest"

# %%
descr_numeric('ponds_nearest')

# %%
flats_sales_data['ponds_nearest'].hist(figsize=(16,4), bins=100, range=(0,100))

# %% [markdown]
# Выбросов вообще нет
#
# Заполняем по аналогии с airports_nearest , cityCenters_nearest и parks_nearest

# %%
# loc_median - здесь сохрним медианы расстояний по населенным пунктам

print('Медианы расстояний ponds_nearest в locality_name : ')
loc_median = flats_sales_data.groupby('locality_name')['ponds_nearest'].median().sort_values()
loc_median = loc_median.dropna()
display(loc_median.head(15))

# Функция для присваивания пропуску значения медианы
def med_insert(loc_dist):
    if loc_dist not in loc_median:
        return np.nan
    return loc_median[loc_dist]


print('Проверка работы med_insert: Сестрорецк - ', med_insert('Сестрорецк')) 
print('Проверка работы med_insert: поселок Зеленогорск - ', med_insert('Зеленогорск'))

# %%
# Выборка для проверки
print('Всего пропущенных значений в столбце =', flats_sales_data['ponds_nearest'].isna().sum())
test_ind = flats_sales_data.loc[(flats_sales_data['locality_name']=='Санкт-Петербург') & (flats_sales_data['ponds_nearest'].isna()==True)].index
print("Всего пропущенных значений в Санкт-Петербург =", len(test_ind))
display(flats_sales_data.loc[test_ind,['locality_name','ponds_nearest']].head(12))

# %%
# ДЕЛАЕМ ЗАМЕНУ
flats_sales_data.loc[flats_sales_data['ponds_nearest'].isna()==True, 'ponds_nearest'] = flats_sales_data['locality_name'].apply(med_insert)

# %%
# ПРОВЕРЯЕМ
display(flats_sales_data.loc[test_ind,['locality_name','ponds_nearest']].head(12))

# %% [markdown]
# Проверим сколько осталось пропусков

# %%
print("Кол-во пропусков оставшихся =", flats_sales_data['parks_nearest'].isna().sum())

# %% [markdown]
# ВЫВОД: было пропусков 14579 осталось 6030 - большую часть значений заполнили, теперь со значениями около 18 тысяч.
# Остальные не заполняем по аналогии с другими столбцами с расстояниями

# %% [markdown]
# #### 22. Столбец "days_exposition"

# %%
 descr_numeric('days_exposition')

# %%
flats_sales_data['locality_name'].value_counts(dropna=False)

# %%
flats_sales_data['days_exposition'].hist(bins=50, figsize=(16,3))

# %%
flats_sales_data['days_exposition'].hist(bins=50, range=(1000,1600), figsize=(16,3))

# %%
flats_sales_data['days_exposition'].hist(bins=50, range=(0,45),figsize=(16,3))

# %% [markdown]
# Данные распределены равномерно, сильных выбросов нет. Удалять ничего не будем

# %%
print('Распределение пропусков по населенным пунктам:')
loc_nan_exp = pd.DataFrame()
loc_nan_exp = flats_sales_data.groupby(flats_sales_data[flats_sales_data['days_exposition'].isna()==True]['locality_name'])['locality_name'].count(). \
                                                          sort_values(ascending=False)

# data.groupby(data.loc[data['days_exposition'].isna()==True,'locality_name'])['locality_name'].count(). \
#                                                                                 sort_values(ascending=False).head(20)
display(loc_nan_exp)

# %% [markdown]
# #### check days_exposition

# %% [markdown]
# Главным фактором влиющим на скорость продажи квартиры является местоположение - locality_name
# Попробуем заполнить пропуски медианами или средними по каждому населенному пункту

# %%
print('Медианы days_exposition в locality_name : ')
loc_median = flats_sales_data.groupby('locality_name')['days_exposition'].median().sort_values()
loc_median = loc_median.dropna()
display(loc_median)

# Функция для присваивания пропуску значения медианы
def loc_med_insert(loc_name):
    if loc_name not in loc_median:
        return np.nan
    return loc_median[loc_name]
print('Проверка работы loc_median: поселок Любань - ', loc_med_insert('поселок Любань')) 
print('Проверка работы loc_median: Санкт-Петербург - ', loc_med_insert('Санкт-Петербург'))

# %%
print('Средние days_exposition в locality_name : ')
loc_mean = flats_sales_data.groupby('locality_name')['days_exposition'].mean().sort_values()
loc_mean = loc_mean.dropna()
display(loc_mean)

# Функция для присваивания пропуску значения медианы
def loc_mean_insert(loc_name):
    if loc_name not in loc_mean:
        return np.nan
    return loc_mean[loc_name]
print('Проверка работы loc_mean: поселок Любань - ', loc_mean_insert('поселок Любань')) 
print('Проверка работы loc_mean: Санкт-Петербург - ', loc_mean_insert('Санкт-Петербург'))

# %% [markdown]
# Выберем медиану для замены пропусков (она менее чувствительна к крайним значениям)

# %%
# Контрольные значения
print(loc_med_insert('Санкт-Петербург'))
print('Санкт-Петербург', flats_sales_data[flats_sales_data['locality_name']=='Санкт-Петербург']['days_exposition'])
print()
print(loc_med_insert('деревня Заневка'))
print('деревня Заневка', flats_sales_data[flats_sales_data['locality_name']=='деревня Заневка']['days_exposition'])
print()
print(loc_med_insert('поселок Любань'))
print('поселок Любань', flats_sales_data[flats_sales_data['locality_name']=='поселок Любань']['days_exposition'])
print()
print(loc_med_insert('поселок Шугозеро'))
print('поселок Шугозеро',flats_sales_data[flats_sales_data['locality_name']=='поселок Шугозеро']['days_exposition'])

# %%
# ЗАМЕНЯЕМ
flats_sales_data.loc[flats_sales_data['days_exposition'].isna()==True, 'days_exposition'] = flats_sales_data['locality_name'].apply(loc_med_insert)

# %%
# Проверим
print('Санкт-Петербург', flats_sales_data[flats_sales_data['locality_name']=='Санкт-Петербург']['days_exposition'])
print('деревня Заневка', flats_sales_data[flats_sales_data['locality_name']=='деревня Заневка']['days_exposition'])
print('поселок Любань', flats_sales_data[flats_sales_data['locality_name']=='поселок Любань']['days_exposition'])
print('поселок Шугозеро',flats_sales_data[flats_sales_data['locality_name']=='поселок Шугозеро']['days_exposition'])

# %% [markdown]
# Проверим сколько осталось пропусков и найдем медианцу столбца

# %%
print("Кол-во пропусков =", flats_sales_data['days_exposition'].isna().sum())
print()
med_day_exp = flats_sales_data['days_exposition'].median()
print('Медиана всего столбца =', med_day_exp)

# %% [markdown]
# В принипе пропусков мало можно их и удалить, но всетаки, заполним их медианой всего столбца, большого влияния (в худшем случае) на анализ оказать не должно

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Пропуски в ['days_exposition'] говорят нам, что квартиры еще не проданы..., неверно терять столь важный признак, → оставляем пропуски

# %%
flats_sales_data['days_exposition'] = flats_sales_data['days_exposition'].fillna(med_day_exp)
print("Кол-во пропусков стало =", flats_sales_data['days_exposition'].isna().sum())

# %%
flats_sales_data['days_exposition'].describe()

# %% [markdown]
# Поменяем тип

# %%
print('Тип до замены', flats_sales_data['days_exposition'].dtype)
flats_sales_data['days_exposition'] = flats_sales_data['days_exposition'].astype(int)
print('Тип после замены', flats_sales_data['days_exposition'].dtype)

# %% [markdown]
# **Столбец скорректирован**

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-info">
# В пункте 3.1 проделано много работы, которую предстояло сделать в следующих пунктах. Ячейки не удаляю, но закомментирую
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Типовые характеристики хрущевок
#
#         общая площадь:
#     1-комнатная — 31-33 кв.м.
#     2-комнатная — 30-46 кв.м.
#     3-комнатная — 55-58 кв.м.
#
# можно предположить, что 4-х комнатная будет в районе 60-62 кв. м.
#
# Слишком жесткие условия фильтрации, потери в записях нерациональны
#
#         all_flats = flats_sales_data.shape[0]
#         good_all_flats = (
#             good_flat_with_1_room.shape[0] +
#             good_flat_with_2_rooms.shape[0] +
#             good_flat_with_3_rooms.shape[0] +
#             good_flat_with_4_rooms.shape[0] +
#             good_flat_with_5_rooms.shape[0] +
#             good_flat_with_lots_rooms.shape[0])
#         print(all_flats - good_all_flats, (all_flats - good_all_flats)/all_flats)

# %% [markdown]
# ### Восстановление пропусков

# %% [markdown]
# Пропуски в floors_total заменим, изучив этаж квартиры и популярные значения всех этажей в доме по данным.

# %%
print(flats_sales_data[flats_sales_data['floors_total'].isna()]['floor'].value_counts())
flats_sales_data['floors_total'].value_counts()

# %% [markdown]
# Дома с указанным этажом квартиры и отсутвием максимального этажа в доме скорей всего подтверждает, что продавец по-умолчанию указал последний этаж в доме, раз не повторил эту информацию. Сводный анализ по количеству этажей по домам говорит о том, что все строки с пропусками встречаются в выборке по максимальной этажности здания.
#
# Соотвественно будем считать, что указанный этаж являеятеся последним этажом в доме.

# %%
 flats_sales_data['floors_total'] = flats_sales_data['floors_total'].fillna(0)

 def fill_floors_total(row):
     if row[6] == 0:
         row[6] = row[8]
     return row

 flats_sales_data = flats_sales_data.apply(fill_floors_total, axis=1)
flats_sales_data['floors_total'].isna().value_counts()

# %% [markdown]
# Попуски в living_area заполним, взяв за основу среднее соотношение жилой площади к общей.

# %%
living_area_ratio_mean = (flats_sales_data['living_area'] / flats_sales_data['total_area']).mean()
living_area_ratio_median = (flats_sales_data['living_area'] / flats_sales_data['total_area']).median()
print(living_area_ratio_mean, living_area_ratio_median, living_area_ratio_mean/living_area_ratio_median)

# %% [markdown]
# Для сравнения полученных результатов из отношения значений в строке, возмем результаты, примененные к выборке в целом.

# %%
living_area_mean = flats_sales_data['living_area'].mean()
living_area_median = flats_sales_data['living_area'].median()
print(living_area_mean, living_area_median, living_area_mean/living_area_median)
total_area_mean = flats_sales_data['total_area'].mean()
total_area_median = flats_sales_data['total_area'].median()
print(total_area_mean, total_area_median, total_area_mean/total_area_median)
living_area_ratio_mean_series = living_area_mean / total_area_mean
living_area_ratio_median_series = living_area_median / total_area_median
print(living_area_ratio_mean_series, living_area_ratio_median_series, living_area_ratio_mean_series/ living_area_ratio_median_series)

# %% [markdown]
# Применим процент жилой площади из переменной living_area_ratio_mean. Заполним пустоты основывась на знании total_area по формуле: *living_area = total_area living_area_ratio_mean*

# %%
flats_sales_data['living_area'] = flats_sales_data['living_area'].fillna(0)

def fill_living_area(row):
    if row[7] == 0:
        row[7] = float(format(row[2] * living_area_ratio_mean, '.2f'))
    return row

flats_sales_data = flats_sales_data.apply(fill_living_area, axis=1)

flats_sales_data['living_area'].isna().value_counts()

# %% [markdown]
# Пропуски в is_apartment заменим на False, так как отсуствие по этому пункту говорит нам, что перед нами обычная квартира.

# %%
flats_sales_data['is_apartment'] = flats_sales_data['is_apartment'].fillna(False)

flats_sales_data['is_apartment'].isna().value_counts()

# %% [markdown]
# Для пропусков в столбце kitchen_area проанализируем соотношение

# %%
kitchen_area_ratio_mean = (flats_sales_data['kitchen_area'] / flats_sales_data['total_area']).mean()
kitchen_area_ratio_median = (flats_sales_data['kitchen_area'] / flats_sales_data['total_area']).median()
print(kitchen_area_ratio_mean, kitchen_area_ratio_median, kitchen_area_ratio_mean/kitchen_area_ratio_median)

# %% [markdown]
# Для заполнения будем использовать среднее соотношение. Если произведение общей площади на это соотношение даст значение меньше 5 кв.м. то будет использовать константу в 5 кв.м.

# %%
flats_sales_data['kitchen_area'] = flats_sales_data['kitchen_area'].fillna(0)

def fill_kitchen_area(row):
    if row[12] == 0:
        normal_fill_kitchen = float(format(row[2] * kitchen_area_ratio_mean, '.2f'))
        if row[4] == 1:
            if normal_fill_kitchen >= 5:
                row[12] = normal_fill_kitchen
            else:
                row[12] = 5
        elif row[4] > 1:
            if normal_fill_kitchen >= 6:
                row[12] = normal_fill_kitchen
            else:
                row[12] = 6
    return row

flats_sales_data = flats_sales_data.apply(fill_kitchen_area, axis=1)

flats_sales_data['kitchen_area'].unique()

# %% [markdown]
# #### check area

# %% [markdown]
# Для пропусков в столбце balcony установим значение 0.

# %%
flats_sales_data['balcony'] = flats_sales_data['balcony'].fillna(0)
flats_sales_data['balcony'].isna().value_counts()

# %% [markdown]
# Посмотрим, какие значения пропущены в locality_name.

# %%
nan_locality_name = flats_sales_data[flats_sales_data['locality_name'].isna()]
nan_locality_name.head()

# %% [markdown]
# Невозможно восстановить данные, если в cityCenters_nearest стоит NaN. Удалим эти значения.

# %%
bad_locality_name = nan_locality_name[nan_locality_name['cityCenters_nearest'].isna()]
bad_locality_name.head()

# %%
bad_index = bad_locality_name.index
print(bad_index)

flats_sales_data.drop(bad_index, inplace=True)
flats_sales_data.loc[2030:2040, :]

# %% [markdown]
# Проведем поиск расстояния по указанному locality_name от центра Санкт-Петербурга. Начнем с категоризации местоположения.

# %%
print(flats_sales_data['locality_name'].value_counts())
flats_sales_data['locality_name'].unique()

# %% [markdown]
# В названиях имеются дубликаты к примеру посёлок Мурино, поселок Мурино и Мурино. Проведем работу над приведением к одному виду столбца locality_name.

# %%
flats_sales_data_copy = copy.deepcopy(flats_sales_data)

bad_locality_name = flats_sales_data_copy[flats_sales_data_copy['locality_name'].isna()]

bad_index = bad_locality_name.index
print(bad_index)

flats_sales_data_copy.drop(bad_index, inplace=True)

def make_short_name(row):
    #print(1, row)
    split_name = row.split()
    new_name = []
    for word in split_name:
        if word[0].isupper():
            new_name.append(word)
    new_name = ' '.join(word for word in new_name)
    #print(2, new_name)
    return new_name

    
flats_sales_data_copy['short_locality_name'] = flats_sales_data_copy['locality_name'].apply(make_short_name)

short_locality_name_keys = flats_sales_data_copy['short_locality_name'].unique()
short_locality_name_keys

# %% [markdown]
# Мы создали список имен для словаря, теперь соотнесем и найдем среднее растояние от названия местности с центром города. Это поможет на заполнить пропуски в locality_name и cityCenters_nearest.

# %%
flats_sales_data_copy['short_locality_name'].unique()

# %%
locality_and_cityCenter_dict = {}

bad_cityCenters_nearest = flats_sales_data_copy[flats_sales_data_copy['cityCenters_nearest'].isna()]

bad_index = bad_cityCenters_nearest.index
print(bad_index)

flats_sales_data_copy.drop(bad_index, inplace=True)
print(flats_sales_data_copy['short_locality_name'].unique())

def make_locality_and_cityCenter_dict(data_frame):
    for name in short_locality_name_keys:
        mean = data_frame[data_frame['short_locality_name'] == name]['cityCenters_nearest'].mean()
        locality_and_cityCenter_dict[name] = mean
        
make_locality_and_cityCenter_dict(flats_sales_data_copy)
locality_and_cityCenter_dict

# %% [markdown]
# Из проведенной обработки данных видно, что не все объявления имеют расстояния и многие деревни, поселки и города не имеют расстояния от центра Санкт-Петербурга. Для гипотезы по расстоянию от центра важны только квартиры в Санкт-Петербурге. Для этого проверим сколько сейчас пропусков в расстоянии с указанным городом Санкт-Петербург.

# %%
locality_and_cityCenter_dict = {}
short_locality_name_keys = flats_sales_data_copy['short_locality_name'].unique()
make_locality_and_cityCenter_dict(flats_sales_data_copy)
print(locality_and_cityCenter_dict)

SP_flats_sales_data = flats_sales_data.query('locality_name == "Санкт-Петербург" and cityCenters_nearest.isna()')
SP_flats_sales_data['cityCenters_nearest'].isna().value_counts()

# %% [markdown]
# Только для этих 59 значений мы восстановим среднее расстояние от центра города.
#
# Для объявлений, чье расстояние от центра менее 15 км, заменим пропуск на Санкт-Петебург. Все остальные пропуски зададим расположение "За пределами города".

# %%
flats_sales_data['locality_name'] = flats_sales_data['locality_name'].fillna('empty')
print(flats_sales_data[flats_sales_data['locality_name'] == 'empty']['cityCenters_nearest'].value_counts())

def fill_locality_name(row):
    if row[14] == 'empty':
        if row[16] < 15000:
            row[14] = 'Санкт-Петебург'
        else:
            row[14] = 'За пределами города'
    return row

flats_sales_data = flats_sales_data.apply(fill_locality_name, axis=1)
flats_sales_data.info()

# %% [markdown]
# parks_around3000 и ponds_around3000 заполним значениями 0.

# %%
flats_sales_data['parks_around3000'] = flats_sales_data['parks_around3000'].fillna('0')
flats_sales_data['ponds_around3000'] = flats_sales_data['ponds_around3000'].fillna('0')
flats_sales_data.info()

# %% [markdown]
# Заполнение столцов airports_nearest, cityCenters_nearest и ponds_nearest не требуется из условий гипотез.
#
# Добавим дополнительный столбец date по first_day_exposition. Просмотрим время последних добавленных объявлений и создадим отдельный столбец времени, который хранит в себе день, месяц и год продажи.

# %%
flats_sales_data['date'] =  pd.to_datetime(flats_sales_data['first_day_exposition'], format='%Y-%m-%d')
flats_sales_data['date'].max()

# %% [markdown]
# Количество пропусков в ceiling_height очень большое и корректировка этих значений может привести к неправильному толкованию.

# %% [markdown]
# #### check area

# %%
# check
flats_sales_data[flats_sales_data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='living_area' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'black', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — Жилая');

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Аномалии проявились на графике (прямая неестественная черта в середине облака) — стоит принять решение или изменить алгоритм заполнения пропусков, или оставить пропуски, или заполнить маркерами
#
# при изменении способа обработки колонок, стоит перепроверить код фильтрации в п.2.4
#
# __Самое важное — приобрести навык__ — любая замена пропусков очень трудоемка по ресурсам, т.к. приходится искать оптимальный вариант и если можно работать, имея пропуски в данных — лучше отказаться от заполнения
#
# но есть другие случаи, когда пропуски заполнять обязательно нужно, на проекте по стат. анализу — внимательно посмотри на пропуски в данных в объединенной таблице (кроме даты оттока клиентов)
#
# в итоге каждый раз мы вынуждены будем принимать решение — заполнять пропуски и как заполнять, или оставлять

# %% [markdown]
# ### Приведение типа данных
#
# Следующие столбцы будут приведены в целочисленный тип(int):
# * last_price. Обычно никто не ставит цену на квартиру в рублях с указанием копеек.
# * floors_total. В домах не может быть половина этажа. Только целые.
# * balcony. Исходя из значений в столце, количество балконов должно быть целым.
# * airports_nearest, cityCenters_nearest, parks_nearest и ponds_nearest. Здесь расстояния указаны в метрах.
# * parks_around3000 и ponds_around3000. Как и в случае с балконами, здесь указывается целое число.
#
# Значения в airports_nearest, cityCenters_nearest, parks_nearest, ponds_nearest и days_exposition не могут быть изменены на int из-за значений NaN.

# %%
flats_sales_data['last_price'] = pd.to_numeric(flats_sales_data['last_price'], downcast='integer')
flats_sales_data['floors_total'] = pd.to_numeric(flats_sales_data['floors_total'], downcast='integer')
flats_sales_data['balcony'] = pd.to_numeric(flats_sales_data['balcony'], downcast='integer')
flats_sales_data['airports_nearest'] = pd.to_numeric(flats_sales_data['airports_nearest'], downcast='integer')
flats_sales_data['cityCenters_nearest'] = pd.to_numeric(flats_sales_data['cityCenters_nearest'], downcast='integer')
flats_sales_data['parks_nearest'] = pd.to_numeric(flats_sales_data['parks_nearest'], downcast='integer')
flats_sales_data['ponds_nearest'] = pd.to_numeric(flats_sales_data['ponds_nearest'], downcast='integer')
flats_sales_data['parks_around3000'] = pd.to_numeric(flats_sales_data['parks_around3000'], downcast='integer')
flats_sales_data['ponds_around3000'] = pd.to_numeric(flats_sales_data['ponds_around3000'], downcast='integer')
flats_sales_data['days_exposition'] = pd.to_numeric(flats_sales_data['days_exposition'], downcast='integer')
flats_sales_data.info()

# %% [markdown]
# Кроме перевода значений в столцах мы видим результат по уменьшению используемой памяти дата фрейма с 3.9 МБ до 3.5 МБ.

# %% [markdown]
# ### Удаление дубликатов

# %% [markdown]
# Для идентификации дубликатов возьмем совпадения по нескольким столбцам - по тем в которых быди все значения изначально и особенно в которых маловероятны совпадения: 1) first_day_exposition (++ его почти не меняли и много разных дат), 2) last_price(++здесь должно быть мало повторении), 3) total_area 4) total_images (вообще не меняли) - этого ВПОЛНЕ достаточно

# %%
dupl2 = flats_sales_data[flats_sales_data[['total_images', 'last_price','first_day_exposition','total_area']].duplicated(keep=False)]
dupl2.sort_values(by='total_images')
print('ПЕРВОНАЧАЛЬНАЯ')
display(dupl1.sort_values(by='first_day_exposition'))
print()
print('ИЗМЕНЕННАЯ')
display(dupl2.sort_values(by='first_day_exposition'))

# %% [markdown]
# Пары дубликатов:
#
# * отличаются только этажом (наверно указан был неправильно) - удалим 19254
# * отличаются этажом, а площадь почти одинаковая 19,8 и 20 - удалим 18358
# * много отличий будем считать, что это разные квартиры
# * отличаются только этажом (наверно указан был неправильно при первона) - удалим 18556

# %%
print("Кол-во строк до удаления",len(flats_sales_data))
flats_sales_data.drop([19254,18358,18556], axis=0, inplace=True)
print("Кол-во строк после удаления",len(flats_sales_data))

# %%
flats_sales_data.reset_index(drop=True, inplace=True)
display(flats_sales_data)
flats_sales_data.info()

# %% [markdown]
# **Вывод**
#
# Всего было строк - 23651, после обработки стало - 23648, удалено 1,26% данных - вполне неплохо.
#
# * в стлобце ceiling_height пропуски заменены медианами
# * столбец first_day_exposition приведен к типу datetime64
# * В столбце ceiling_height заменили большую часть на медиану. Здесь были обнаружены ошибочно введенные значения, в которых справа присутствовал лищний ноль,- исправили
# * В столбцах living_area и kitchen_area произведена взаимосвязанная заменя медианами. Так же учтены квартиры студии (их 149), - в строках где студии в столбце kitchen_area оставлено NaN.
# * В числовых столбцах заменены типы на int, кроме столбцов с площадями(округлено до 0,1), и столбцов с расстояниями (оставили float - здесь мрого пропусков)
# * в столбце days_exposition пропуски заполненны медианами в зависимости от населенного пункта
# * Обрезаны сильные выбросы в столбцах где они имели место.
# * Удалено 3 дубликата
# * ! В столбцах с расстояниями заменяли пропуски средними значениями по каждому населенному пункту (удалось заполнить совсем мало значений) и при обработке было выясненно , что полностью невозможно заполнить столбцы с расстояниями: airports_nearest, parks_nearest, ponds_nearest и особенно важный cityCenters_nearest. Единственная возможность заполнить пропуски в них - заполнить средней или медианой всего столбца - но в таком случае при решении задач дальнейшего анализа это сильно может исказать результаты! Поэтому при анализе, там где будет затронут столбец cityCenters_nearest, будем довольствоваться 18737 (-27%!) строками, где присутствуют значения в этом столбце.
# * **В ДатаФрейм "matches_True" - сохранены строки в которых пропуски в расстояниях(Баг-Репорт)**
# * Столбы days_exposition и 4 столбца с расстояниями заполнялись по одинаковому алгоритму.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит переформатировать неявные дубликаты, остались наименования
#
#         'городской поселок Янино-1' и 'городской посёлок Янино-1'

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total'
#
# стоит учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 2.4. существует два подхода
#
# Можно механически бороться с выбросами, ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, несколько записей со стоимостью квадратного метра выше 1-го млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры менее 10-ти и более 200-та квадратных метров по жилой площади можно считать редкостями

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось выполнить пункт 2.4 из брифа проекта
#
# 2.4.	Найдите и устраните редкие и выбивающиеся значения.
#
# __Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%__

# %%
# check
flats_sales_data.locality_name.nunique()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир


(
   flats_sales_data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'total_area', 'ceiling_height', 'kitchen_area', 'floors_total'
#
# стоит учесть наличие пропусков при фильтрации данных

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    flats_sales_data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.0012, 0.01, .5, .99, .9988]) # выбираем размах в 0,9976 квантилей 
    .style.format("{:,.2f}")
)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# они помогают увидеть редкости и аномалии в данных

# %% [markdown]
# ## Шаг 3. Посчитайте и добавьте в таблицу

# %% [markdown]
# Рассчитаем цену квадратного метра. Это основная метрика при работе с квартирами.

# %%
flats_sales_data['price_per_metre'] =(flats_sales_data['last_price'] / flats_sales_data['total_area'] * 100).round()/100
flats_sales_data['price_per_metre']

# %% [markdown]
# Добавим столбцы: день недели, месяц и год публикации.

# %%
flats_sales_data['weekday'] = flats_sales_data['date']
flats_sales_data['month'] = flats_sales_data['date']
flats_sales_data['year'] = flats_sales_data['date']

def make_weekday_month_year(row):
    row[24] = row[22].weekday()
    row[25] = row[22].month
    row[26] = row[22].year
    return row

flats_sales_data = flats_sales_data.apply(make_weekday_month_year,axis=1)
flats_sales_data.head()

# %%
flats_sales_data['sq_metr_pr'] = flats_sales_data['last_price'] / flats_sales_data['total_area']
flats_sales_data['sq_metr_pr'] = flats_sales_data['sq_metr_pr'].astype(int)
display(flats_sales_data['sq_metr_pr'].sample(3))
display(flats_sales_data.sample(3))
flats_sales_data['sq_metr_pr'].dtype

# %% [markdown]
# День недели, месяц и год публикации объявления

# %%
flats_sales_data['day_exp'] = flats_sales_data['first_day_exposition'].dt.weekday
flats_sales_data['month_exp'] = flats_sales_data['first_day_exposition'].dt.month
flats_sales_data['year_exp'] = flats_sales_data['first_day_exposition'].dt.year
display(flats_sales_data[['day_exp', 'month_exp', 'year_exp']].sample(8))
display(flats_sales_data.sample(3))

# %% [markdown]
# Этаж квартиры; варианты — первый, последний, другой (firtst, last, other)

# %%
flats_sales_data.head()

# %%
# flats_sales_data['cat_floor'] = 'other'
# # flats_sales_data['cat_floor'] = data['floor'].where(data['floor']==1,'firtst', 'other')
# # flats_sales_data['cat_floor'] = data['floor'].where(data['floor']==1, 'other')

flats_sales_data['cat_floor'] = np.nan # Новый столбец - категории этажа: первый, последний, другой 

def floor_insert(row):
    if row['floor']==1:
        return 'первый'
    elif row['floor']==row['floors_total']:
        return 'последний'
    else:
        return 'другой'

flats_sales_data['cat_floor'] = flats_sales_data.apply(floor_insert, axis=1)

print(flats_sales_data['cat_floor'].value_counts(dropna=False))

# %% [markdown]
# Составим категоризацию для этажей.

# %%
def categorize_floor(row):
    if row[8] == 1:
        return 'первый'
    elif row[8] == row[6]:
        return 'последний'
    else:
        return 'другой'
    
flats_sales_data['floor_category'] = flats_sales_data.apply(categorize_floor,axis=1)
flats_sales_data['floor_category'].value_counts()

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />У нас нет на проекте задачи найти отношение площадей, это артефакт со старых версий проекта ...
#
#     flats_sales_data['living_area_ratio'] = (flats_sales_data['living_area'] / flats_sales_data['total_area']* 100).round()/100
#     flats_sales_data['kitchen_area_ratio'] = (flats_sales_data['kitchen_area'] / flats_sales_data['total_area']* 100).round()/100
#
# __На проекте данные параметры не используются__

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит выполнить пункт проекта
#
# •	расстояние до центра города в километрах (переведите из м в км и __округлите до целых значений__).

# %% [markdown]
# ## Проведите исследовательский анализ данных и выполните инструкции:

# %% [markdown]
# Разарботаем функцию для постороения графиков.

# %%
def make_hist_by_serie(serie, bins=0):
    serie_description = serie.describe()
    mean = serie_description[1]
    std = serie_description[2]
    d_min = serie_description[3]
    q1 = serie_description[4]
    median = serie_description[5]
    q3 = serie_description[6]
    d_max = serie_description[7]
    iqr = q3-q1
    left_border = q1 - iqr*1.5
    if left_border < d_min:
        left_border = d_min
    right_border = q3 + iqr*1.5
    if right_border > d_max:
        right_border = d_max
    if bins == 0:
        bins = right_border - left_border
        if bins>100:
            bins = 100
        elif bins < 1:
            bins = abs(bins*10)+1
        bins = int(bins)
    else:
        bins = bins
    serie.hist(bins=bins, range=(left_border, right_border))
    print(serie_description)
    return (left_border, right_border)

# %% [markdown]
# ### Изучение параметров - площадь, цена, число комнат, высота потолков. Построение гистограммы для каждого параметра.

# %% [markdown]
# **площадь - total_area**

# %%
flats_sales_data['total_area'].hist(bins=300)

# %%
total_area_borders = make_hist_by_serie(flats_sales_data['total_area'])

# %% [markdown]
# Больше всех квартир находяться в районе от 30 до 65 кв.м. Выбросы сыше 300 кв.м. обусловлены либо большими планировками либо отдельными частными домами.

# %%
flats_sales_data['price_per_metre'].hist(bins=300)

# %%
price_per_metre_borders = make_hist_by_serie(flats_sales_data['price_per_metre'])

# %% [markdown]
# Больше всех квартир находяться в районе от 60 до 120 тыс. рублей за кв.м.

# %%
flats_sales_data['rooms'].hist(bins=16)

# %%
rooms_borders = make_hist_by_serie(flats_sales_data['rooms'])

# %% [markdown]
# Здесь закономерность имеет верную природы. Работа с данными не требует корректировки.

# %%
flats_sales_data['ceiling_height'].hist(bins=100)

# %%
ceiling_height_borders = make_hist_by_serie(flats_sales_data['ceiling_height'])

# %% [markdown]
# Большинсво кварnир имеют высоту от 2.5 до 2.65 м.
#
# Избавимся от выбросов по значимым для нас факторам: площадь, цена, число комнат, высота потолков. Созданная функция дает границы значимых данных и исключает выбросы в них.

# %%
print('Количество значений до удаления выбросов:', flats_sales_data.shape[0])
good_by_area_flats_sales_data = flats_sales_data.query(
    '@total_area_borders[0] <= total_area <=  @total_area_borders[1]')
print('Количество значений хороших по общей площади:', good_by_area_flats_sales_data.shape[0])
good_by_price_per_metre_flats_sales_data = flats_sales_data.query(
    '@price_per_metre_borders[0] <= price_per_metre <=  @price_per_metre_borders[1]')
print('Количество значений хороших по цене за кв.м.:', good_by_price_per_metre_flats_sales_data.shape[0])
good_by_rooms_flats_sales_data = flats_sales_data.query(
    '@rooms_borders[0] <= rooms <=  @rooms_borders[1]')
print('Количество значений хороших по поличеству комнат:', good_by_rooms_flats_sales_data.shape[0])
good_by_ceiling_height_flats_sales_data = flats_sales_data.query(
    '@ceiling_height_borders[0] <= ceiling_height <=  @ceiling_height_borders[1]')
print('Количество значений хороших по высоте потолков:', good_by_ceiling_height_flats_sales_data.shape[0])

# %% [markdown]
# Проведем поочередный отсев выбросов и создадим финальную выборку. Выбросы по цене и высоте потолков будем игнорировать.

# %%
old_new_len_flats_sales_data = flats_sales_data.shape[0]
flats_sales_data = (flats_sales_data
                    .query('@total_area_borders[0] <= total_area <=  @total_area_borders[1]')
                    .query('@rooms_borders[0] <= rooms <=  @rooms_borders[1]')
            )
print('Количество значений до обработки:',old_new_len_flats_sales_data)
print('Количество значений после обработки:',flats_sales_data.shape[0])
print('Процент удаленных данных:', '{:.2%}'.format(
    (old_new_len_flats_sales_data - flats_sales_data.shape[0])/old_new_len_flats_sales_data))

# %% [markdown]
# **цена - last_price**

# %%
descr_numeric('last_price')

# %%
flats_sales_data['last_price'].hist(bins=100,range=(0,30000000))

# %% [markdown]
# Из гистораммы видно, что больше всего квартир продается за 3-4 млн. руб

# %% [markdown]
# **число комнат - rooms**

# %%
descr_numeric('rooms')

# %% [markdown]
# Прекрасно видно, что самые популярные квартиры - 1комнатная(чуть больше 8000) и 2комнатные(около 8000). 3комнатных тоже довольно много - чуть меньше 6000, ну а дальше кол-во сильно сокращаетя. Ясно видна зависимость - чем больше комнат, тем меньше таких квартир. Очень похоже на распределение Пуассона

# %% [markdown]
# **высота потолков - ceiling_height**

# %%
descr_numeric('ceiling_height')

# %% [markdown]
# Больше всего квартир с высотой потолков 250 - 300 см, подавляющее большинство почти половина с высотой 265 см. Остальные высоты довольно редки - нестандартный размер и чем выше тем это наибольшая редкость. А высоты ниже нормального диапазона тоже редкость, потому что уже такие дома не строят или там просто уменьшен потолок (подвесные, натяжные потолки и т.д.). Вполне похоже на распределение Пуассона

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для выполнения проекта стоит получить одну очищенную выборку в п.2.4, сначала данные чистим, затем фиксируем параметры для отчета в четвертом разделе

# %% [markdown]
# **этаж квартиры - floor**

# %%
descr_numeric('floor')

# %% [markdown]
# Видим, что чаще выбирают квартиры на 2-3 этажах и, чем выше этаж, тем интерес к ним ниже. Больше всего покупают квартиры на 2х этажах - возможно это связано с подъемом мебели на этаж и меньшей стоимостью квартир на этих этаж. Интерес к квартипвм заметно ниже - связано это, возможно, с тем, что из-зa близocти к зeмлe и пoдвaлy в квapтиpe в зимнee вpeмя мoгyт быть xoлoдныe пoлы, мнoгиe жильцы пepвыx этaжeй oтмeчaют пocтoянный шyм c yлицы, рaccчитывaть нa гoлoвoкpyжитeльныe пeйзaжи нe пpиxoдитcя. B лyчшeм cлyчae этo бyдeт coбcтвeнный пaлиcaдник или кpacивый, цвeтyщий кycт.

# %% [markdown]
# **Срок продаж - days_exposition**

# %%
days_exposition_borders = make_hist_by_serie(flats_sales_data['days_exposition'])

# %%
flats_sales_data['days_exposition'].describe()

# %%
plt.ylim(0,500)
flats_sales_data.boxplot(column='days_exposition') 
plt.show()

# %% [markdown]
# Исследуя гистограмму продаж и диаграмму размаха можно видеть, что среднее время продажи квартиры 95 дней. Большая часть значений лежит за диапазоном 420 дней (1.5 межквартального размаха, добавленного к третьему квартилю). Это выглядит правдоподобным. Самыми быстрыми продажами можно назвать продажу в один день. Самой долгой продажей (если не брать во внимание выбросы, которые лежат за 1.5 межквартального размаха, добавленного в третьей квартилии)-427 дней.

# %%
plt.ylim(0,1700)
flats_sales_data.boxplot(column='days_exposition')
plt.show()

# %% [markdown]
# Посторил диаграмму размаха со всеми выбросами

# %%
flats_sales_data.sort_values(by='days_exposition',ascending=False).head()

# %%
current_days_exposition_date=flats_sales_data.query('days_exposition<420')

# %% [markdown]
# Убрали выбросы находящиеся за 1.5 межквартальным интервалом, добавленного к Q3

# %%
current_days_exposition_date['days_exposition'].hist(bins=100,range=(0,500))

# %% [markdown]
# Убрал выбросы находящиеся за 1.5 межквартальным интервалом, добавленного к Q3. Всего наблюдается 4 пика. Самый большой пик- 95 дней, есть еще пики 50 дней, 70 дней и 10 дней. Не могу сказать, что это артифакты, тк реально это возможно. Большая часть выбросов лежит за диапазоном 420 дней и они стремяться к 0. Принял решение от них избавиться.

# %%
current_days_exposition_date['last_price'].describe()

# %%
plt.ylim(100000,15000000)
current_days_exposition_date.boxplot(column='last_price')
plt.show()

# %% [markdown]
# На диаграмме размаха видно, что в выбросы попадают квартиры свыше 11 млн. руб

# %%
current_days_exposition_date.sort_values(by='last_price',ascending=True).head(100)

# %% [markdown]
# Смотрю самую дорогую квартиру. Данные правдивые. Такие квартиры существуют.

# %% [markdown]
# **расстояние до ближайшего аэропорта - airports_nearest**

# %%
descr_numeric('airports_nearest')

# %% [markdown]
# **расстояние до ближайшего парка -parks_nearest**

# %%
descr_numeric('parks_nearest')

# %% [markdown]
# **площадь кухни - kitchen_area**

# %%
descr_numeric('kitchen_area')

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Осталось добавить недостающи из 14-ти обязательных гистограмм
#
# Шаг 4. Проведите исследовательский анализ данных:
# 1.	Изучите следующие параметры объектов:
#     +	общая площадь;
#     +	жилая площадь;
#     +	площадь кухни;
#     +	цена объекта;
#     +	количество комнат;
#     +	высота потолков;
#     +	этаж квартиры;
#     +	тип этажа квартиры («первый», «последний», «другой»);
#     +	общее количество этажей в доме;
#     +	расстояние до центра города в метрах;
#     +	расстояние до ближайшего аэропорта;
#     +	расстояние до ближайшего парка;
#     +	день и месяц публикации объявления.
#
#
# __Постройте отдельные гистограммы для каждого из этих параметров.__ Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Осталось добавить 10 обязательных гистограмм из 14-ти
#
# Шаг 4. Проведите исследовательский анализ данных:
# 1.	Изучите следующие параметры объектов:
#     +	общая площадь;
#     +	жилая площадь;
#     +	площадь кухни;
#     +	цена объекта;
#     +	количество комнат;
#     +	высота потолков;
#     +	этаж квартиры;
#     +	тип этажа квартиры («первый», «последний», «другой»);
#     +	общее количество этажей в доме;
#     +	расстояние до центра города в метрах;
#     +	расстояние до ближайшего аэропорта;
#     +	расстояние до ближайшего парка;
#     +	день и месяц публикации объявления.
#
#
# __Постройте отдельные гистограммы для каждого из этих параметров.__ Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.

# %% [markdown]
# #### Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.

# %% [markdown]
# Создадим срез от 7 дней до 360.

# %%
# check
flats_sales_data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5));

flats_sales_data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0, 40);

# %%
flats_sales_data_by_days_exposition = flats_sales_data.query('7 <= days_exposition <= 360')
print(flats_sales_data_by_days_exposition['days_exposition'].describe())
flats_sales_data_by_days_exposition['days_exposition'].hist(bins=100)

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выборка data['days_exposition'] имеет длинный правый хвост, не стоит обрезать подобный хвост на таких значениях, оптимально ориентироваться на значения 0,99 квантиля, это где-то 1200 дней ...
#
#         flats_sales_data_by_days_exposition = flats_sales_data.query('7 <= days_exposition <= 360')
#
# Для определения хвостов стоит использовать гистограммы ...

# %%
flats_sales_data_by_days_exposition['days_exposition'].hist(bins=61, range=(40,100))

# %% [markdown]
# Много квартир продается за 30 и 60 дней. Так же есть локальный пик в 95 дней. Имеются техники риэлторов , которые продают квартиры за 45, 60 или 90 дней как главное правильно своей работы.
#
# Проведем удаление выбросов по дням продажи. Возьмем за левую границу 7 дней, за правую - правую границу в по квантилям 496.

# %%
old_new_len_flats_sales_data = flats_sales_data.shape[0]
flats_sales_data = flats_sales_data.query('7 <= days_exposition <= @days_exposition_borders[1]')
print('Количество значений до обработки:',old_new_len_flats_sales_data)
print('Количество значений после обработки:',flats_sales_data.shape[0])
print('Процент удаленных данных:', '{:.2%}'.format(
    (old_new_len_flats_sales_data - flats_sales_data.shape[0])/old_new_len_flats_sales_data))

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит пересчитать статистики скорости продажи после восстановления пропусков, заполнение пропусков медианой искажает расчет скорости продаж

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит вернуть часть потерянных значений ..., слишком жесткие условия фильтрации применены, потеряно более 10% данных
#
#         flats_sales_data = flats_sales_data.query('7 <= days_exposition <= @days_exposition_borders[1]')

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#     flats_sales_data = flats_sales_data.query('7 <= days_exposition <= @days_exposition_borders[1]')
#
# Так мы познакомились с особенностью фильтрации в библиотеке пандас, все NaN убегают вместе со значениями, которые не подходят под нашу фильтрацию, поэтому процент потери записей огромен
#
# Минус 3000 записей с пропусками и минус 1500 записей без пропуска, слишком жесткие условия фильтрации ...
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками
#
# <b>алгоритм фильтрации столбца с пропусками: задаем основное условие фильтрации, + прибавляем условие не трогать записи с пропусками</b>
#
# стоит обратить внимание на весь код фильтрации, т.к. в нескольких колонках встречаются пропуски

# %% [markdown]
# ### Стоимость квартиры
# 1. Какие факторы больше всего влияют на стоимость квартиры?
#
# По общей информации на стоимость квартиры влияет ее местоположение (в центра города - на окранине, в хорошем районе - в неблагополучном, близко от местро/транспортных узлов или нет), тип жилья (частный дом - квартира, новый дом - хрущевка/аварийный, наличие лифта или другой инфраструктуры), расположение квартиры в доме (какой этаж, сколько квартир на этаж), площадь и планировка квартиры, вид из окна и общее состояние квартиры (новая, с ремонтом, без ремонта).
#
# 2. Изучите, зависит ли цена от квадратного метра, числа комнат, удалённости от центра.
#
# Составим корреляционные зависимости предложенных факторов.

# %%
prise_area_rooms_center = flats_sales_data.loc[:,['price_per_metre', 'total_area', 'rooms', 'cityCenters_nearest']]
prise_area_rooms_center.head()

# %%
prise_area_rooms_center.corr()

# %%
pd.plotting.scatter_matrix(prise_area_rooms_center, figsize=(15, 15))

# %% [markdown]
# В целом получаем:
#
# - Цена имеет слабую зависимость от площади. Большинство квартир продаются в районе от 60 тыс. до 140 тыс за кв. м. с площадью от 28 кв.м. до 80 кв.м.
# - Количество комнат отрицательно влияет на стоимость, но слабо. Комнаты напрямую определяют размер общей площади. Самые распространенные квартиры имеют от 1 до 3 комнат.
# - Дальность от центра уменьшает стоимость достаточно. Это и логично - чем ближе к центру, тем легче до него добраться. Основной поток квартир сконцентрирован на расстоянии до 20 км.
# 3. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.
#
# Построим гистограммы для каждой категории и выделим укрупненный диапозон с ценой.

# %%
#print(flats_sales_data[flats_sales_data['floor_category'] == 'первый']['price_per_metre'].describe())
#flats_sales_data[flats_sales_data['floor_category'] == 'первый']['price_per_metre'].hist(bins=50)
make_hist_by_serie(flats_sales_data[flats_sales_data['floor_category'] == 'первый']['price_per_metre'])

# %% [markdown]
# Квартиры на первом этаже не популярны. Больше всего квартир продали за 60 тыс. за кв.м. и после 110 тыс. за кв.м. начинается спад по продажам этих квартир.

# %%
#print(flats_sales_data[flats_sales_data['floor_category'] == 'последний']['price_per_metre'].describe())
#flats_sales_data[flats_sales_data['floor_category'] == 'последний']['price_per_metre'].hist(bins=50)
make_hist_by_serie(flats_sales_data[flats_sales_data['floor_category'] == 'последний']['price_per_metre'])

# %% [markdown]
# Квартир на последнем этаже также много продали за 70 тыс. за кв. м. и спад начинается после 110 тыс. за кв.м. Однозначно квартиры на последнем этаже дороже, чем на первом.

# %%
#print(flats_sales_data[flats_sales_data['floor_category'] == 'другой']['price_per_metre'].describe())
#flats_sales_data[flats_sales_data['floor_category'] == 'другой']['price_per_metre'].hist(bins=100)
make_hist_by_serie(flats_sales_data[flats_sales_data['floor_category'] == 'другой']['price_per_metre'])

# %% [markdown]
# Основные продажи квартир на остальных этажах проходят в районе от 75 тыс. за кв.м. до 120 тыс. за кв.м. и идет на спад. Это говорит о том, что другие этажи определенно стоят дороже, чем первые. Их стоимость в целом выше от квартир на последнем этаже, но нет так сильно. В целом люди платять болше за квартиры не на первом и не на последнем этаже.

# %% [markdown]
# Также изучите зависимость от даты размещения: дня недели, месяца и года.
#
# Построим корреляционные зависимости.

# %%
prise_weekday_month_year = flats_sales_data.loc[:,['price_per_metre', 'weekday', 'month', 'year']]
prise_weekday_month_year.head()

# %%
prise_weekday_month_year.corr()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Коэффициент корреляции рассчитывается для всех зависимостей из задания, исключая параметры - день недели и месяц — это не эффективно, т.к. это нелинейные параметры
#
# чтобы они стали линейными, январь месяц 2015 года должен стать третьим и т.д., т.е. мы должны сделать перекодировку ...

# %%
#print(prise_weekday_month_year[prise_weekday_month_year['weekday'] == 0]['last_price'].describe())
prise_weekday_month_year[prise_weekday_month_year['weekday'] == 0]['price_per_metre'].hist(bins=100, range=(0,200000))
prise_weekday_month_year[prise_weekday_month_year['weekday'] == 1]['price_per_metre'].hist(bins=100, range=(0,200000), alpha=0.5)

# %%
prise_weekday_month_year[prise_weekday_month_year['weekday'] == 2]['price_per_metre'].hist(bins=100, range=(0,200000))
prise_weekday_month_year[prise_weekday_month_year['weekday'] == 3]['price_per_metre'].hist(bins=100, range=(0,200000), alpha=0.5)

# %%
prise_weekday_month_year[prise_weekday_month_year['weekday'] == 4]['price_per_metre'].hist(bins=100, range=(0,200000))
prise_weekday_month_year[prise_weekday_month_year['weekday'] == 5]['price_per_metre'].hist(bins=100, range=(0,200000), alpha=0.5)

# %%
prise_weekday_month_year[prise_weekday_month_year['weekday'] == 6]['price_per_metre'].hist(bins=100, range=(0,200000))

# %% [markdown]
# В общей картине стомость квартиры не зависит от дня продажи. Единственное что меняется - это количество проданных квартир. Больше всего квартир продают за будние дни, когда у риелторов и агенств основной режим работы.
#
# Изучим гистограммы по столбцу месяцев.

# %%
prise_weekday_month_year[prise_weekday_month_year['month'] == 1]['price_per_metre'].hist(bins=100, range=(0,200000) )
prise_weekday_month_year[prise_weekday_month_year['month'] == 2]['price_per_metre'].hist(bins=100, range=(0,200000), alpha=0.5)

# %%
prise_weekday_month_year[prise_weekday_month_year['month'] == 3]['price_per_metre'].hist(bins=100, range=(0,200000))
prise_weekday_month_year[prise_weekday_month_year['month'] == 4]['price_per_metre'].hist(bins=100, range=(0,200000), alpha=0.5)

# %%
prise_weekday_month_year[prise_weekday_month_year['month'] == 5]['price_per_metre'].hist(bins=100, range=(0,200000))
prise_weekday_month_year[prise_weekday_month_year['month'] == 6]['price_per_metre'].hist(bins=100, range=(0,200000), alpha=0.5)

# %%
prise_weekday_month_year[prise_weekday_month_year['month'] == 7]['price_per_metre'].hist(bins=100, range=(0,200000))
prise_weekday_month_year[prise_weekday_month_year['month'] == 8]['price_per_metre'].hist(bins=100, range=(0,200000), alpha=0.5)

# %%
prise_weekday_month_year[prise_weekday_month_year['month'] == 9]['price_per_metre'].hist(bins=100, range=(0,200000))
prise_weekday_month_year[prise_weekday_month_year['month'] == 10]['price_per_metre'].hist(bins=100, range=(0,200000), alpha=0.5)

# %%
prise_weekday_month_year[prise_weekday_month_year['month'] == 11]['price_per_metre'].hist(bins=100, range=(0,200000))
prise_weekday_month_year[prise_weekday_month_year['month'] == 12]['price_per_metre'].hist(bins=100, range=(0,200000), alpha=0.5)

# %% [markdown]
# По графикам видно, что основные продажи так же идут от 75 тыс. за кв.м. до 110 тыс. за кв.м.каждый месяц. Отличается лишь количество продаж на декабрь и январь. В эти месяцы меньше всего продаж квартир.
#
# Пройдемся по столбцу год.

# %%
prise_weekday_month_year[prise_weekday_month_year['year'] == 2014]['price_per_metre'].hist(bins=50, range=(0,200000))
prise_weekday_month_year[prise_weekday_month_year['year'] == 2015]['price_per_metre'].hist(bins=50, range=(0,200000), alpha=0.5)

# %%
prise_weekday_month_year[prise_weekday_month_year['year'] == 2016]['price_per_metre'].hist(bins=50, range=(0,200000))
prise_weekday_month_year[prise_weekday_month_year['year'] == 2017]['price_per_metre'].hist(bins=50, range=(0,200000), alpha=0.5)

# %%
prise_weekday_month_year[prise_weekday_month_year['year'] == 2018]['price_per_metre'].hist(bins=50, range=(0,200000))
prise_weekday_month_year[prise_weekday_month_year['year'] == 2019]['price_per_metre'].hist(bins=50, range=(0,200000), alpha=0.5)

# %% [markdown]
# По графикам видно небольшое смещение пика вправо. Легкая положительная зависимость есть, она исходит из инфляции в стране.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исследование зависимости параметров от цены кв. метра выполнено классно.
#
# __Стоит поменять параметр для поиска зависимостей на last_price (согласно заданию проекта)__
#
# по условиям проекта мы ищем зависимости общей цены квартиры от параметров ..., т.к. стоимость кв. м. расчетная величина от двух параметров, в т.ч. от площади
#
# Шаг 4. Проведите исследовательский анализ данных:
#
# 3.	Какие факторы больше всего влияют __на общую (полную) стоимость объекта?__
#     Изучите, зависит ли цена от:
#     +	общей площади;
#     +	жилой площади;
#     +	площади кухни;
#     +	количества комнат;
#     +	этажа, на котором расположена квартира (первый, последний, другой);
#     +	даты размещения (день недели, месяц, год).
#
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
#
# __для первых трех параметров не стоит агрегировать данные для поиска линейной зависимости__
#
# Советы по графикам:
#
# + зависимость параметров (от площади, удалённости от центра) оптимальнее рассматривать на точечных графиках (тип scatter),
# + динамику на линейных (это про сравнение цен за год, месяц, день недели), — стоит сгруппировать значения и рассчитать среднее или медианное значение
# + сравнение цен на барах (для сравнение средней стоимости квартиры по трем категориям), — стоит сгруппировать значения и рассчитать среднее или медианное значение

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="4", color = "black">
# <br />
#
# Шаг 4. Проведите исследовательский анализ данных:
#
# 3.	Какие факторы больше всего влияют __на общую (полную) стоимость объекта?__
#     Изучите, зависит ли цена от:
#     +	общей площади;
#     +	жилой площади;
#     +	площади кухни;
#     +	количества комнат;
#     +	этажа, на котором расположена квартира (первый, последний, другой);
#     +	даты размещения (день недели, месяц, год).
#
# __Стоит проверить наличие всех 8-ми обязательных графиков в разделе__

# %% [markdown]
# ### Выберите 10 населённых пунктов с наибольшим числом объявлений.
# 1. Посчитайте среднюю цену квадратного метра в этих населённых пунктах.
# 2. Выделите населённые пункты с самой высокой и низкой стоимостью жилья
#
# Для оптимизации поиска названия применим функцию для создания коротких имен, чтобы исключить дубликаты.

# %%
flats_sales_data['short_locality_name'] = flats_sales_data['locality_name'].apply(make_short_name)
top_10_locality_name = flats_sales_data['short_locality_name'].value_counts()[:10]
print(top_10_locality_name)
top_10_locality_name = top_10_locality_name.index
top_10_locality_name

# %%
top_10_pivot_table_mean = (flats_sales_data
                      .query('short_locality_name in @top_10_locality_name')
                      .pivot_table(index='short_locality_name', values='price_per_metre', aggfunc='mean')
                      .sort_values('price_per_metre', ascending=False))
top_10_pivot_table_mean

# %%
top_10_pivot_table_min_max = (flats_sales_data
                      .query('short_locality_name in @top_10_locality_name')
                      .pivot_table(index='short_locality_name', values='price_per_metre', aggfunc=['min','max']))
top_10_pivot_table_min_max

# %%
top_10_pivot_table_mean.plot(kind='line', rot=60)

# %% [markdown]
# Из данных видно во все лидеры вырвался Санкт-Петербург.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера </b></font>
# <br />
# <font size="3", color = "black">
# <br />      Можно развернуть график
#
#      kind='barh'

# %% [markdown]
# ### Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра.

# %% [markdown]
# 1. Выделите квартиры в Санкт-Петербурге ('locality_name'). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений.
# 2. После этого посчитайте среднюю цену для каждого километра.
# 3. Постройте график: он должен показывать, как цена зависит от удалённости от центра.
# 4. Определите границу, где график сильно меняется — это и будет центральная зона.

# %%
SP_flats_sales_data = flats_sales_data.query('locality_name == "Санкт-Петербург"')
SP_flats_sales_data.info()

# %%
SP_flats_sales_data['kilometers_from_center'] = (SP_flats_sales_data['cityCenters_nearest']/1000).round()
SP_flats_sales_data['kilometers_from_center'].value_counts().index

# %%
price_per_km = (SP_flats_sales_data
               .pivot_table(index='kilometers_from_center', values='price_per_metre', aggfunc='mean'))
price_per_km

# %%
plot_price_per_km = price_per_km
plot_price_per_km['km'] = price_per_km.index
plot_price_per_km

# %%
price_per_km.plot(x='km', y='price_per_metre' ,kind='line')

# %% [markdown]
# Я не понимаю что не так '_'

# %%
# check
SP_flats_sales_data.cityCenters_nearest

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />У тебя уже округленные км.
#
#         SP_flats_sales_data.cityCenters_nearest
#
# повторное округление
#
#         SP_flats_sales_data['kilometers_from_center'] = (SP_flats_sales_data['cityCenters_nearest']/1000).round()
#         SP_flats_sales_data['kilometers_from_center'].value_counts().index
#
# превращает все значения в нули ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Молодец, у тебя получилось сгруппировать и построить график изменения средней цены кв. метра в зависимости от расстояния от центра
#
#
# Для выполнения 5-го пункта стоит поменять параметр расчета с цены за квадрат на общую стоимость квартиры и построить линейный график
#
#
#         5.	Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изучить записи, которые привели к выбросу на 27-м км.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре

# %% [markdown]
# ### Выделите сегмент квартир в центре.
# 1. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков.
# 2. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления).
# 3. Сделайте выводы. Отличаются ли они от общих выводов по всему городу?

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />    У нас нет на проекте задачи анализировать все квартиры центра отдельно
#
# Только длина Невского проспекта порядка 4,5 км. (центральная улица города), для центра Питера 3 км., слишком маленький радиус

# %%
SP_center_flats_sales_data = SP_flats_sales_data.query('kilometers_from_center <= 3')
SP_center_flats_sales_data.info()

# %%
#print(SP_center_flats_sales_data['total_area'].describe())
#SP_center_flats_sales_data['total_area'].hist(bins=30)
make_hist_by_serie(SP_center_flats_sales_data['total_area'],30)

# %% [markdown]
# В центре много больших квартир от 45 до 100 кв.м.

# %%
#make_hist_by_serie(SP_center_flats_sales_data['price_per_metre'])
#print(SP_center_flats_sales_data['price_per_metre'].describe())
make_hist_by_serie(SP_center_flats_sales_data['price_per_metre'],30)

# %% [markdown]
# Стоимость этих квартир в среднем выше. Если для всей выборки пик был в районе от 80 до 130 за кв.м., то здесь пик смещен от 80 тыс. за кв.м. до 140 тыс. за кв.м.

# %%
#print(SP_center_flats_sales_data['rooms'].describe())
#SP_center_flats_sales_data['rooms'].hist(bins=4)
make_hist_by_serie(SP_center_flats_sales_data['rooms'],4)

# %% [markdown]
# В центре больше всего квартир с 2-3 комнатами.

# %%
#print(SP_center_flats_sales_data['ceiling_height'].describe())
#SP_center_flats_sales_data['ceiling_height'].hist(bins=30, range=(2,5))
make_hist_by_serie(SP_center_flats_sales_data['ceiling_height'],20)

# %% [markdown]
# Самая популярная высота потолка 3 м, и также много квартир с высотой до 3.2 м.
#
# Проведем корреляционные матрицы для остальных факторов по тому же принципу.=

# %%
SP_center_prise_area_rooms_center = SP_center_flats_sales_data.loc[:,['price_per_metre', 'total_area', 'rooms', 'cityCenters_nearest']]
SP_center_prise_area_rooms_center.corr()

# %% [markdown]
# Зависмимость от общей площади сменила знак, но осталось слабой.

# %%
SP_center_prise_weekday_month_year = SP_center_flats_sales_data.loc[:,['price_per_metre', 'weekday', 'month', 'year']]
SP_center_prise_weekday_month_year.corr()

# %% [markdown]
# Тоже похоже на основные показатели данных.
#
# Проведем сравнительные выводы между центром города и общей выборкой.

# %%
make_hist_by_serie(flats_sales_data['total_area'])

# %%
#print(flats_sales_data['total_area'].describe())
#SP_center_flats_sales_data['total_area'].describe()
make_hist_by_serie(SP_center_flats_sales_data['total_area'],30)

# %% [markdown]
# Медиана и среднее выше, чем у всей выборки. Это значит, что в центре больше просторных квартир.

# %%
make_hist_by_serie(flats_sales_data['price_per_metre'])

# %%
#print(flats_sales_data['price_per_metre'].describe())
#SP_center_flats_sales_data['price_per_metre'].describe()
make_hist_by_serie(SP_center_flats_sales_data['price_per_metre'],30)

# %% [markdown]
# Медиана выросла на 18 тысяч, а среднее на 32 тысяч. Высокая цена оправдывает местоположение квартир в центре.

# %%
make_hist_by_serie(flats_sales_data['rooms'])

# %%
#print(flats_sales_data['rooms'].describe())
#SP_center_flats_sales_data['rooms'].describe()
make_hist_by_serie(SP_center_flats_sales_data['rooms'],4)

# %% [markdown]
# В центре больше квартир с количеством комнат с 2 до 3, когда из общих данных много квартир с 1-4 комнатами.

# %%
make_hist_by_serie(flats_sales_data['ceiling_height'])

# %%
#print(flats_sales_data['ceiling_height'].describe())
#SP_center_flats_sales_data['ceiling_height'].describe()
make_hist_by_serie(SP_center_flats_sales_data['ceiling_height'],20)

# %% [markdown]
# Медиана и средняя высота потолков выше в центре. Это означает, что в центре города у людей больше простора из-за типа застроек.

# %%
print(prise_area_rooms_center.corr())
SP_center_prise_area_rooms_center.corr()

# %% [markdown]
# Квартиры в центре имеют меньше зависимостей от площади или удаленности от центра.
#
# Выросла зависимость от количество комнат в 2 раза.

# %% [markdown]
# print(prise_weekday_month_year.corr())
# SP_center_prise_weekday_month_year.corr()

# %% [markdown]
# Здесь имеется небольшой прирост положительной кореляции от дня недели.
#
# Кореляция по месяцу выросла в 25 раз. Это означает в центре неохотней покупаю под конец года.
#
# С зависимостью от года произошло увеличение в 2.5 раз и сохранила свой знак.
#
# Выведем это на графиках по параметрам.
#
# Цена от общей площади.

# %%
sns.set(style='ticks')
        
x = flats_sales_data['total_area']
y = flats_sales_data['price_per_metre']
sns.jointplot(x, y, kind="kde", color="#4CB391",  ylim = (25000,200000))

x = SP_center_flats_sales_data['total_area']
y = SP_center_flats_sales_data['price_per_metre']
sns.jointplot(x, y, kind="kde", color="#FFB391", ylim = (25000,200000))

# %% [markdown]
# Цена от количества комнат.

# %%
sns.set(style='ticks')
        
x = flats_sales_data['rooms']
y = flats_sales_data['price_per_metre']
sns.jointplot(x, y, kind="kde", color="#4CB391", ylim = (25000,200000))

x = SP_center_flats_sales_data['rooms']
y = SP_center_flats_sales_data['price_per_metre']
sns.jointplot(x, y, kind="kde", color="#FFB391", ylim = (25000,200000))

# %% [markdown]
# Цена от высоты потолков.

# %%
sns.set(style='ticks')
        
x = flats_sales_data['ceiling_height']
y = flats_sales_data['price_per_metre']
sns.jointplot(x, y, kind="kde", color="#4CB391", ylim = (25000,200000), xlim = (2,4))

x = SP_center_flats_sales_data['ceiling_height']
y = SP_center_flats_sales_data['price_per_metre']
sns.jointplot(x, y, kind="kde", color="#FFB391", ylim = (25000,200000), xlim = (2,4))

# %% [markdown]
# Цена от удаленности от центра.

# %%
sns.set(style='ticks')
        
x = flats_sales_data['cityCenters_nearest']
y = flats_sales_data['price_per_metre']
sns.jointplot(x, y, kind="kde", color="#4CB391", ylim = (25000,200000))

x = SP_center_flats_sales_data['cityCenters_nearest']
y = SP_center_flats_sales_data['price_per_metre']
sns.jointplot(x, y, kind="kde", color="#FFB391", ylim = (25000,200000))

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит исключить предупреждения. Иногда их бывает слишком много, поэтому важно уметь их скрывать. В этом тебе поможет библиотека warnings. Попробуй найти подходящий метод и убрать предупреждения.

# %% [markdown]
# Цена от дня недели.

# %%
sns.set(style='ticks')
        
x = flats_sales_data['weekday']
y = flats_sales_data['price_per_metre']
sns.jointplot(x, y, kind="kde", color="#4CB391", ylim = (25000,200000))

x = SP_center_flats_sales_data['weekday']
y = SP_center_flats_sales_data['price_per_metre']
sns.jointplot(x, y, kind="kde", color="#FFB391", ylim = (25000,200000))

# %% [markdown]
# Цена от месяца.

# %%
sns.set(style='ticks')
        
x = flats_sales_data['month']
y = flats_sales_data['price_per_metre']
sns.jointplot(x, y, kind="kde", color="#4CB391", ylim = (25000,200000))

x = SP_center_flats_sales_data['month']
y = SP_center_flats_sales_data['price_per_metre']
sns.jointplot(x, y, kind="kde", color="#FFB391", ylim = (25000,200000))

# %% [markdown]
# Цена от года.

# %%
sns.set(style='ticks')
        
x = flats_sales_data['year']
y = flats_sales_data['price_per_metre']
sns.jointplot(x, y, kind="kde", color="#4CB391", ylim = (25000,200000))

x = SP_center_flats_sales_data['year']
y = SP_center_flats_sales_data['price_per_metre']
sns.jointplot(x, y, kind="kde", color="#FFB391", ylim = (25000,200000))

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Объясни пожалуйста, какое явное отличие мы видим на подобных графиках, на твой выбор — любое
#
#     Использование данных палитр дает наглядное представление характерных отличий всех данных (изумрудный цвет(#4CB391)) от данных в центре Санкт-Петербурга(оранжевый цвет(#FFB391)).

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для отчета стоит использовать более простые и доступные формы
#
# самое важное, если использованы подобные виды графиков, стоит подробно расшифровать, что мы сравниваем и какой результат получаем на двух графиках

# %% [markdown]
# **Вывод**
# Проведя анализ данных по зависимостям цены за квадратный метр по отношению к другим факторам имеются следующие выводы:
#
# - Для проживания в городе люди пытаются найти квартиры стоимостью 80 тыс. +- 20 тыс. за кв.м. с как минимум одной комнатой, потолком в 2.7 метра и планировкой от 40 кв.м.
# - Основные продажи квартир случаются через 30 - 200 дней. Большнство обусловлены планами риэлторов и системами продаж.
# - На стоимость квартиры положительно влияет общая площадь, количество комнат, год продажи, отрицательно - количество комнат, удаленность от центра, день и месяц продажи.
# - Санкт-Петербур имеет самую большую стоимость и самую большую стоимость за кв.м.
# - В центре квартиры в целом лучше и их цена оправдана их местоположением.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# После изучения данных можно сказать, что можно работать с таблицами, в которых встречаются пропущенные значения. Данные всё-таки лучше очищать от явных "выбросов", но возможно чистить данные придётся после этапа исследовательского анализа данных. В нашем примере - это дорогие квартиры, которые портили корреляции и графики зависимости полной стоимости от разных параметров. Из необычных особенностей:
#
# * В 27 км от центра Санкт-Петербурга есть недвижимость по цене почти равная недвижимости в 8 км. от центра;
# В ТОП-10 входят в основном ближайшие к Санкт-Петербургу города и самые крупные города области:
#     + Пушкин;
#     + Гатчина;
#     + Всеволожск;
#     + Выборг.
#
# * Цена в основном зависит от площади квартиры, но корреляция с этажностью(не первый и не последний) видна на графике.
# Таких квартир явно больше и они явно дороже.
# * Быстрые продажи это до 95 дней, а необычно долгие - свыше 181 дня.\
# * **Выбросы** Количество объявлений, которые сняты через:
#     + 45 дней: 872
#     + 60 дней: 536
#     + 90 дней: 204
#
# Предполагаю, что данные взяты с площадки, где неактивные объявления автоматически снимаются, если пользователь не продлит время размещения через определёный срок. Либо присутсвует платное рамещение. Нужно связаться с тем, кто предоставляет данные.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Технически вывод хороший, есть сравнения показателей, инсайты, анализ рынка недвижимости, молодец
#
# Осталось перепроверить итоговый вывод после исправления всех комментариев

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#
# Критические ❌ комментарии
#
# + принять решение после проверки корректности заполнения пропусков синтетическими данными
# + отформатировать неявные дубликаты
# + настроить фильтрацию редких значений в п. 2.4
# + добавить гистограмм в п.4.1
# + подправить выполнение п. 4.3
# + исследовать аномалии в п.4.5
# + добавить расшифровку к доп. графикам — отличие центра Питера от всей выборки
# + поправить итоговый вывод
#
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
#
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)
#
# [Как выбрать определенные столбцы из DataFrame](https://dfedorov.spb.ru/pandas/03.%20%D0%9A%D0%B0%D0%BA%20%D0%B2%D1%8B%D0%B1%D1%80%D0%B0%D1%82%D1%8C%20%D0%BF%D0%BE%D0%B4%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D0%B8%D0%B7%20DataFrame_.html?ysclid=l9sps5lt6g576766938)
#
# [How to visualise data using histograms in Pandas](https://practicaldatascience.co.uk/data-science/how-to-visualise-data-using-histograms-in-pandas)

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
